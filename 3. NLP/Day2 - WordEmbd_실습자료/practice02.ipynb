# %%
import gensim
# Out:
# /home1/wklee/anaconda3/envs/onmt_t17/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# # Step1: prepare the corpus for training

# %%
# Step 1. 주어진 data로 gensim을 활용하여 word2vec 모델 학습

# 학습을 위한 데이터 로딩 -- Data 준비
class TextIterator(object):
	def __init__(self, fname):
		self.fname = fname

	def __iter__(self):
		for line in open(self.fname):
			yield line.split()

filename = 'newskor.txt'
sentences = TextIterator(filename)

# %% [markdown]
# # Step 2, 3: Training & Load Word2Vec model

# %%
# Hyperparams
train = True # train flag (True: train model / False: load trained model)
SIZE = 300 # vector size
WINDOW = 5 # context window
SG = 1 # 1 for skip-gram / otherwise cbow
MIN_COUNT = 10 # ignores all words appearing lower than min_count
WORKERS = 20 # cpu cores

# %%
if train:
    model = gensim.models.Word2Vec(
        vector_size=SIZE, window=WINDOW, sg=SG, 
        min_count=MIN_COUNT, workers=WORKERS
    )
    model.build_vocab(sentences) # prepare model vocab
    model.train(sentences, total_examples=model.corpus_count, epochs=5)
    model.save('newskor.model')
else:
    model = gensim.models.Word2Vec.load('newskor.model')

# %%
model.wv.index_to_key # See vocabs
# Out:
# ['하',
#  '이',
#  '.',
#  '는',
#  '을',
#  'ㄴ',
#  '다',
#  '의',
#  '에',
#  '를',
#  '은',
#  '어',
#  '있',
#  '고',
#  '으로',
#  '가',
#  '였',
#  'ㄹ',
#  '되',
#  ',',
#  '에서',
#  '었',
#  ')',
#  '(',
#  '로',
#  '것',
#  '도',
#  '등',
#  '과',
#  '들',
#  '지',
#  '와',
#  '여',
#  '일',
#  '기',
#  '·',
#  'ㄴ다',
#  '적',
#  '수',
#  '아',
#  '%',
#  '게',
#  '원',
#  '년',
#  '2',
#  '았',
#  '3',
#  '1',
#  '다고',
#  '“',
#  '”',
#  '월',
#  '위하',
#  '대하',
#  '말하',
#  '시장',
#  '면',
#  '업체',
#  '따르',
#  '하고',
#  '않',
#  '만',
#  '까지',
#  '‘',
#  '’',
#  '밝히',
#  '명',
#  '및',
#  '부터',
#  '다가',
#  '미국',
#  '며',
#  '이라고',
#  '4',
#  '개',
#  '대',
#  '나',
#  '오',
#  '대표',
#  '국내',
#  '한국',
#  '5',
#  '다는',
#  '던',
#  '서비스',
#  '습니다',
#  '개발',
#  '계획',
#  '인',
#  '주',
#  '통하',
#  '제품',
#  '없',
#  '또',
#  '화',
#  '정부',
#  '면서',
#  '최근',
#  '한',
#  '으며',
#  '6',
#  '지난해',
#  '중',
#  '그',
#  '사업',
#  '올해',
#  '중국',
#  '보이',
#  '크',
#  '받',
#  '일본',
#  '이번',
#  '10',
#  '보다',
#  '내',
#  '기업',
#  '경우',
#  '보',
#  '대통령',
#  '같',
#  '-',
#  '관련',
#  '기술',
#  '에게',
#  '지만',
#  '때문',
#  '전',
#  '전망',
#  'LG',
#  '라고',
#  '7',
#  '달러',
#  '현재',
#  '예정',
#  '지나',
#  '어서',
#  'ㄴ다는',
#  '특히',
#  '이상',
#  '8',
#  '북한',
#  '사',
#  '시스템',
#  '문제',
#  '김',
#  '삼성전자',
#  '겠',
#  '늘',
#  '간',
#  '나서',
#  '관계자',
#  '잇',
#  '9',
#  '아니',
#  '라는',
#  '용',
#  '인터넷',
#  '높',
#  '라',
#  '내년',
#  '솔루션',
#  '위',
#  '데',
#  '회사',
#  '시키',
#  '장비',
#  'ㅁ',
#  '씨',
#  '업계',
#  '이날',
#  '때',
#  '다면서',
#  '두',
#  '세계',
#  '도록',
#  '예상',
#  '추진',
#  '게임',
#  'PC',
#  '그러나',
#  '말',
#  '확대',
#  '한편',
#  '수출',
#  '공급',
#  '함께',
#  'ㄴ다고',
#  '전자',
#  '매출',
#  '구축',
#  '많',
#  '못하',
#  '점',
#  '으나',
#  '20',
#  '규모',
#  '투자',
#  '분야',
#  '이후',
#  'TV',
#  '서울',
#  'IT',
#  '가운데',
#  '지역',
#  '경기',
#  '세',
#  '뒤',
#  '시작',
#  'SK',
#  '사용',
#  '디지털',
#  '시',
#  '자',
#  '기존',
#  '지원',
#  '라면서',
#  '가격',
#  '단말기',
#  '이나',
#  '제공',
#  '정도',
#  '방침',
#  '어야',
#  'LCD',
#  '발표',
#  '본격',
#  '텔레콤',
#  '알리',
#  '11',
#  '30',
#  '분기',
#  '이르',
#  'ㅂ니다',
#  '12',
#  '노',
#  '확보',
#  '열리',
#  '가장',
#  '정보',
#  '조사',
#  '대상',
#  '기록',
#  '기대',
#  '출시',
#  '여야',
#  '가능성',
#  '판매',
#  '안',
#  '더',
#  '사장',
#  '가능',
#  '*',
#  '모두',
#  '도입',
#  '이용',
#  '다른',
#  '상황',
#  '기반',
#  '강화',
#  '진출',
#  '수준',
#  '갖',
#  '키',
#  '설명',
#  '필요',
#  '앞',
#  '증가',
#  '포함',
#  '휴대폰',
#  '결과',
#  '∼',
#  '해외',
#  '비하',
#  '기능',
#  '0',
#  '올',
#  '공동',
#  '후',
#  '15',
#  '차',
#  '전략',
#  '일부',
#  '지적',
#  '처음',
#  '분',
#  '방식',
#  '방안',
#  '반도체',
#  '마련',
#  '형',
#  '2000',
#  '주요',
#  '회',
#  '만들',
#  '는데',
#  '주장',
#  '결정',
#  '분석',
#  '생산',
#  '나오',
#  '요',
#  '전체',
#  '국가',
#  '당',
#  '나타나',
#  '통합',
#  '사업자',
#  '가지',
#  '관리',
#  '새롭',
#  '△',
#  '그동안',
#  '삼성',
#  '의원',
#  'KT',
#  '이라크',
#  '중심',
#  '미',
#  '참여',
#  '경쟁',
#  '우리',
#  '요구',
#  '장관',
#  'e',
#  '수요',
#  '이미',
#  '제',
#  '산업',
#  'D',
#  '추가',
#  '프로젝트',
#  '최대',
#  '각각',
#  '칩',
#  '내용',
#  '초',
#  '물론',
#  '다양',
#  '거나',
#  '서버',
#  '나가',
#  '시간',
#  '알',
#  '적용',
#  '전하',
#  '좋',
#  '오르',
#  '성장',
#  '벌이',
#  '상',
#  '약',
#  '50',
#  '16',
#  '실시',
#  '검찰',
#  '박',
#  '콘텐츠',
#  '네트워크',
#  '정책',
#  '마케팅',
#  '뿐',
#  '하지만',
#  '총',
#  '모바일',
#  '평가',
#  '대한',
#  '배',
#  '감독',
#  '하반기',
#  '부문',
#  '13',
#  '25',
#  '사람',
#  '선정',
#  '고객',
#  '처럼',
#  '향후',
#  '계속',
#  '활용',
#  '방송',
#  '들어가',
#  '14',
#  '듣',
#  '열',
#  '장',
#  '이란',
#  '계',
#  '온라인',
#  '경제',
#  '설립',
#  '만큼',
#  '"',
#  '17',
#  '사실',
#  '회장',
#  '대비',
#  '발생',
#  '자체',
#  '차세대',
#  '올리',
#  '상태',
#  '높이',
#  '적극',
#  '인하',
#  '한나라당',
#  '계약',
#  '협력',
#  '성공',
#  '차지',
#  '선보이',
#  '앞서',
#  '21',
#  '어렵',
#  '진행',
#  '떨어지',
#  '유럽',
#  '운영',
#  '18',
#  '개월',
#  '이루',
#  '목표',
#  '달',
#  '집중',
#  '보안',
#  '팀',
#  '상반기',
#  '관심',
#  '=',
#  '번',
#  '지난달',
#  '검토',
#  '작업',
#  '다시',
#  '협상',
#  '100',
#  '우려',
#  '자신',
#  '40',
#  '통신',
#  '소프트웨어',
#  '모든',
#  '하나',
#  '확인',
#  '인치',
#  '아직',
#  '그룹',
#  '더욱',
#  '동안',
#  '지금',
#  '공략',
#  '&',
#  '교수',
#  '직접',
#  '측',
#  '기준',
#  '국민',
#  '구성',
#  '대부분',
#  '곳',
#  '생각',
#  '코리아',
#  '놓',
#  '강조',
#  "'",
#  '24',
#  '반면',
#  '카드',
#  '국회',
#  '총리',
#  '맞',
#  '센터',
#  '건',
#  '실적',
#  '입장',
#  '타',
#  '가량',
#  '기간',
#  '정',
#  '밖에',
#  '보도',
#  '데이터',
#  '19',
#  '유지',
#  '지속',
#  '논의',
#  '프로그램',
#  '대형',
#  '개선',
#  '이달',
#  '방문',
#  '갖추',
#  '체결',
#  '첫',
#  '과정',
#  '후보',
#  '램',
#  '모델',
#  '별',
#  '공개',
#  '현지',
#  '사건',
#  '준비',
#  '달리',
#  '효과',
#  '단계',
#  '으로써',
#  '상대',
#  'B',
#  '찾',
#  '2002',
#  '최고',
#  '내놓',
#  '여부',
#  '23',
#  '당시',
#  '관하',
#  '공격',
#  '조',
#  '환경',
#  '무선',
#  '평균',
#  '서',
#  '상용',
#  '가입자',
#  '또한',
#  '22',
#  '제휴',
#  '사이트',
#  '이유',
#  '주가',
#  '급',
#  '각종',
#  '확산',
#  '국제',
#  '이전',
#  '회담',
#  '지원하',
#  '부품',
#  '외국인',
#  '처리',
#  '각',
#  '회의',
#  '영화',
#  '덧붙이',
#  '대회',
#  '26',
#  '영업',
#  '합의',
#  '웹',
#  '영향',
#  '정통부',
#  '활동',
#  '비용',
#  '내리',
#  '월드컵',
#  '아시아',
#  '대학',
#  '전국',
#  '줄이',
#  '27',
#  '의견',
#  '핵심',
#  '호',
#  '잡',
#  '해결',
#  '역시',
#  '빠르',
#  '거치',
#  '28',
#  '없이',
#  '차원',
#  '이런',
#  '행사',
#  '설치',
#  '남',
#  '러시아',
#  '치',
#  '상승',
#  '선수',
#  '얻',
#  '경쟁력',
#  '보유',
#  '활성화',
#  '늘리',
#  '민주당',
#  '바',
#  '경',
#  '주력',
#  '강',
#  '부시',
#  '오후',
#  '넘',
#  '이다',
#  '만나',
#  '2003',
#  '최종',
#  '확정',
#  '연구',
#  '줄',
#  '비중',
#  '29',
#  '전환',
#  '표준',
#  'DMB',
#  '브랜드',
#  '수사',
#  '마치',
#  '대응',
#  'KTF',
#  '노력',
#  '메모리',
#  '채택',
#  '부담',
#  '전문',
#  'ㄴ데',
#  '독일',
#  '신규',
#  '우선',
#  '모듈',
#  '중요',
#  'PDA',
#  '어도',
#  '관계',
#  '비즈니스',
#  '조치',
#  '작년',
#  '업무',
#  '동시',
#  '대기업',
#  '력',
#  '관련업계',
#  '대만',
#  '오전',
#  'SW',
#  '기관',
#  '참석',
#  '음',
#  '는다',
#  '핵',
#  '모니터',
#  '으면',
#  '중소기업',
#  '테러',
#  '대로',
#  '영국',
#  '감소',
#  '외국',
#  '인증',
#  '60',
#  'A',
#  '제기',
#  '개인',
#  '펼치',
#  '초고속',
#  '맞추',
#  '전문업체',
#  'ㄴ다면서',
#  '개최',
#  '다음',
#  '보고서',
#  '형태',
#  '현',
#  '하락',
#  '거래',
#  '비롯',
#  '달성',
#  '자사',
#  '변화',
#  '돈',
#  '소비자',
#  '2001',
#  '잇따르',
#  '인수',
#  '협의',
#  '상품',
#  '소재',
#  '달하',
#  '무현',
#  '아이',
#  '인식',
#  '혐의',
#  '자금',
#  '아야',
#  '판단',
#  '무선인터넷',
#  '의하',
#  '사용자',
#  '리눅스',
#  '움직임',
#  '경찰',
#  '살',
#  '당초',
#  '교육',
#  '요청',
#  '일반',
#  '보내',
#  '역할',
#  '이동통신',
#  '는지',
#  '시즌',
#  '물량',
#  '려는',
#  '제안',
#  '미치',
#  'CDMA',
#  '제도',
#  'm',
#  '군',
#  '은행',
#  '공장',
#  '자리',
#  '해',
#  '구매',
#  '글로벌',
#  'SI',
#  '반대',
#  '외',
#  '막',
#  '씩',
#  'PDP',
#  '위원장',
#  '새',
#  '라인',
#  '제시',
#  '인사',
#  '신',
#  '정치',
#  '이동전화',
#  '투입',
#  '사이',
#  '수입',
#  '안정',
#  '2005',
#  '고려',
#  '2004',
#  '미군',
#  '낮',
#  '많이',
#  '프랑스',
#  '다음달',
#  '구체적',
#  '예산',
#  '일정',
#  '노트북',
#  '카메라',
#  '인력',
#  '잘',
#  '국산',
#  '별도',
#  '차례',
#  '청와대',
#  '국',
#  '제외',
#  'ㄴ다면',
#  '계기',
#  '제출',
#  '그치',
#  '여성',
#  '주목',
#  '의미',
#  '플랫폼',
#  '포털',
#  '채널',
#  'ㄴ지',
#  '대변인',
#  '망',
#  '이하',
#  '쉽',
#  '회복',
#  '컴퓨터',
#  '부상',
#  '맡',
#  '선',
#  '로서',
#  'C',
#  '건설',
#  '전쟁',
#  '완료',
#  '적극적',
#  '우리나라',
#  '연결',
#  '컨소시엄',
#  '포인트',
#  '여러',
#  '승',
#  '공식',
#  '줄어들',
#  '등록',
#  '시행',
#  '산',
#  '전문가들',
#  '유통',
#  '불법',
#  '단체',
#  '연구원',
#  '속',
#  '중단',
#  '앞두',
#  '리',
#  '하며',
#  '쓰',
#  '추세',
#  '모습',
#  '비',
#  '구현',
#  '법',
#  '이제',
#  '디스플레이',
#  '다르',
#  '발전',
#  '양산',
#  '사진',
#  '31',
#  '폰',
#  'G',
#  '/',
#  '또는',
#  '유엔',
#  '어떤',
#  '최',
#  '세우',
#  '우승',
#  '전문가',
#  '70',
#  '끝나',
#  '자료',
#  '종합',
#  '지분',
#  '이뤄지',
#  '거두',
#  '사례',
#  'ㄹ지',
#  '방법',
#  '감안',
#  '80',
#  'MP',
#  '테스트',
#  '최초',
#  '치열',
#  '출신',
#  '제작',
#  '같이',
#  'HP',
#  '열린우리당',
#  '컨설팅',
#  '탑재',
#  '메일',
#  'DVD',
#  '세계적',
#  '플레이어',
#  '업종',
#  '아파트',
#  'ERP',
#  '사실상',
#  '형성',
#  '맺',
#  '성능',
#  '불구하',
#  '조직',
#  '대책',
#  '번째',
#  '해당',
#  '거의',
#  '연말',
#  '대신',
#  '가동',
#  '그렇',
#  '연계',
#  '참가',
#  '자동차',
#  '촉구',
#  '주식',
#  '성과',
#  '언론',
#  '국방부',
#  '전달',
#  '나라',
#  '연간',
#  '겪',
#  '여기',
#  '주도',
#  '속도',
#  '전반',
#  '내부',
#  '담당',
#  '논란',
#  '진입',
#  '양',
#  '피해',
#  'M',
#  '벤처기업',
#  '육성',
#  '인도',
#  '평',
#  '바꾸',
#  '비롯하',
#  'IBM',
#  '날',
#  '이며',
#  '파',
#  '통과',
#  '영상',
#  '불과하',
#  '?',
#  '반영',
#  '부',
#  '현상',
#  '실제',
#  '개국',
#  '연속',
#  '조정',
#  '공정',
#  'TFT',
#  '통신사업자',
#  '모르',
#  '수주',
#  '장기',
#  '99',
#  '모으',
#  '대규모',
#  '대폭',
#  '전세계',
#  '반응',
#  '훈련',
#  '금융',
#  '채',
#  '바탕',
#  '매각',
#  '학교',
#  '위성',
#  '전화',
#  '위치',
#  '풀이',
#  '이동',
#  '착수',
#  '선거',
#  '세트',
#  '인프라',
#  '사람들',
#  '멀티미디어',
#  '점유율',
#  '과거',
#  '이미지',
#  '입',
#  '인정',
#  '하루',
#  '체제',
#  '권',
#  '니',
#  '시험',
#  '케이블',
#  '지상파',
#  '능력',
#  '강하',
#  '보급',
#  '분위기',
#  '부족',
#  '내다보',
#  '의사',
#  '국내외',
#  '스럽',
#  '정하',
#  '발언',
#  '경영',
#  '힘들',
#  '보고',
#  '상당',
#  '표준화',
#  '300',
#  '시기',
#  '정상',
#  '신청',
#  '증시',
#  '제조업체',
#  '컬러',
#  '성',
#  '기회',
#  '정보통신부',
#  '길',
#  '과제',
#  '어떻',
#  '힘',
#  '마무리',
#  '인기',
#  '전략적',
#  '어느',
#  '수립',
#  '홍',
#  '90',
#  '부처',
#  '의혹',
#  '작',
#  '바로',
#  '몇',
#  '마켓',
#  '야',
#  '께',
#  '부분',
#  '싶',
#  'R',
#  ...]

# %%
## check word embed result
word = '버스'
print(model.wv[word])
print('size of vector: ', len(model.wv[word]))
# Out:
# [-1.28682405e-01  5.66599131e-01  5.75886369e-01  2.05671415e-01
#  -1.72221541e-01  3.49116772e-01 -3.24239224e-01  7.51419187e-01
#  -6.87707663e-02  3.15315202e-02  2.46695161e-01 -6.65922165e-02
#  -3.45187187e-01 -2.83971041e-01 -1.36189714e-01 -1.99062064e-01
#  -3.15497130e-01  1.30809888e-01  4.94904025e-03 -3.91583219e-02
#   7.37383589e-02  2.59026163e-03  1.92904159e-01 -6.42431453e-02
#   1.27675921e-01 -2.45442927e-01 -1.81874096e-01  1.80150792e-01
#  -7.89898783e-02  1.73874304e-01  1.37507200e-01 -2.25318745e-01
#   5.39747834e-01 -3.03388089e-01 -3.09321105e-01  1.16513215e-01
#   5.43617122e-02 -4.63663757e-01  5.56160696e-02  2.39711702e-01
#   1.05050929e-01 -1.72165722e-01  1.26839712e-01  5.35689354e-01
#   6.05753779e-01  7.69956827e-01 -4.84324954e-02 -3.56478523e-03
#  -2.95956852e-03 -3.81394811e-02  1.91248447e-01  1.67245209e-01
#   5.35007529e-02  1.44819096e-01  2.94060051e-01  8.69548880e-03
#   1.89116925e-01  1.04932394e-02  2.53554583e-02 -2.55335987e-01
#  -5.11766076e-01  4.68417257e-02 -1.87845662e-01  5.74199110e-02
#  -2.84020901e-01  3.02185088e-01  5.65864779e-02  1.78573236e-01
#  -1.53569341e-01 -1.54672176e-01  1.74021408e-01  3.12420607e-01
#  -4.10045952e-01 -5.01546383e-01  8.01452696e-02  4.39230323e-01
#  -3.37243050e-01  1.05388761e-01 -2.00436234e-01 -1.82454452e-01
#   4.74857897e-01 -2.94742316e-01 -1.59805492e-01  2.40378514e-01
#  -3.92872542e-02 -2.05564275e-01  1.45778924e-01  2.53729559e-02
#   1.85714602e-01  2.81549931e-01  5.88160872e-01  1.02570325e-01
#  -1.13624997e-01 -5.61264992e-01  2.23059997e-01  4.48507667e-01
#  -2.15061814e-01  3.61268483e-02 -1.36158288e-01  2.92867631e-01
#  -1.88274402e-02 -7.26014599e-02 -2.28579074e-01 -2.11846039e-01
#   1.19525611e-01 -1.31054834e-01 -3.03977486e-02  4.28101748e-01
#  -1.06096983e-01  3.37081879e-01 -3.40786017e-02 -1.13323174e-01
#   2.85748184e-01 -1.08884536e-01  4.08383846e-01 -6.23401664e-02
#   3.64615768e-02 -5.52876443e-02  7.12738335e-01 -4.30717438e-01
#   2.19392523e-01 -1.34370252e-01  7.62346804e-01  1.36374295e-01
#  -9.64799598e-02 -4.65614438e-01  2.25481123e-01 -6.40243411e-01
#   1.19006477e-01 -3.86441439e-01  2.44026005e-01  3.89884382e-01
#   1.44224778e-01 -7.23057464e-02 -3.26589018e-01  2.12725878e-01
#   1.85384765e-01 -1.60202339e-01 -1.87552944e-01  3.71937782e-01
#   1.64061323e-01 -4.36521508e-02 -1.79884359e-01 -5.05215883e-01
#  -5.31611204e-01  2.38258988e-01  5.28835535e-01  4.48271602e-01
#  -5.14429033e-01 -6.09892681e-02 -4.30344902e-02  2.04574212e-01
#  -1.05696924e-01  1.41475201e-01  2.38325447e-01  3.05006176e-01
#   7.16682374e-02  4.07442123e-01  2.50263453e-01 -9.47968662e-02
#   6.63561523e-02  3.65531206e-01  8.11147168e-02  1.83650345e-01
#  -1.90842539e-01 -1.86804757e-01 -1.12663180e-01 -1.08946972e-01
#  -2.73085069e-02  1.02718882e-01  1.47740066e-01 -4.30033475e-01
#   1.35050967e-01 -1.76695526e-01 -1.34915952e-02  1.16729513e-01
#   2.00112298e-01 -1.18580446e-01 -6.01005405e-02  2.94590563e-01
#   2.84465905e-02  2.73085944e-02 -3.02514166e-01 -3.55696082e-01
#   8.98713246e-02 -2.05910847e-01 -4.42031950e-01 -2.79467672e-01
#  -1.76715925e-02  1.86155304e-01  1.00161098e-01  2.00379491e-01
#  -6.05626367e-02  9.26357228e-03  1.49204075e-01  1.00176902e-02
#   1.36613220e-01  5.86147197e-02  2.10779339e-01  4.89958115e-02
#   3.71524960e-01 -4.03607100e-01  3.14557523e-01  2.59872794e-01
#   2.43982360e-01 -3.83829743e-01 -2.06890531e-04  2.57623732e-01
#   3.35774899e-01  1.72168091e-02  1.29004568e-01 -2.98173606e-01
#  -9.03880000e-02 -6.57282248e-02  6.21959604e-02  1.17828539e-02
#   3.22067142e-02 -4.14425343e-01 -2.33455654e-02  1.11130379e-01
#   4.26384769e-02  2.88279176e-01 -2.28976663e-02  3.91028345e-01
#   1.71734728e-02  2.66668171e-01 -8.61307085e-02 -1.41925842e-01
#  -3.81771684e-01  1.65274978e-01  3.08991015e-01  2.94622183e-01
#  -3.58068585e-01 -1.31515458e-01 -4.35578257e-01  1.29622728e-01
#   1.48598969e-01 -3.71588796e-01  2.39966899e-01 -2.62845129e-01
#  -1.67509273e-01 -1.21693328e-01  4.88598794e-02 -3.20762575e-01
#  -4.71501127e-02 -3.88054252e-01 -1.18847989e-01  1.73831403e-01
#  -2.07431406e-01  6.92431256e-02 -5.92402697e-01  5.00557236e-02
#   4.28578049e-01 -2.81283796e-01 -2.20949784e-01 -1.26916051e-01
#   3.35688680e-01  1.95367366e-01 -2.57364511e-01  3.21443975e-01
#   1.00341365e-01 -2.80474186e-01  4.03078258e-01 -2.05139115e-01
#   3.88307385e-02  2.37635419e-01 -1.23839177e-01 -2.63108075e-01
#  -2.90904611e-01  3.63426149e-01 -1.34742796e-01 -1.77287474e-01
#   1.72752559e-01 -1.82105392e-01  2.85291612e-01  1.17097110e-01
#   6.41974211e-01  2.42742449e-01 -3.21217366e-02 -1.70989912e-02
#   1.33366987e-01  2.16891274e-01  1.50829867e-01  6.30586315e-03
#   8.36703330e-02 -4.32016224e-01 -8.81433859e-02  2.98157573e-01
#   8.76485929e-03 -6.47244155e-02 -6.93608820e-02 -9.42441747e-02
#   4.15717773e-02  3.38127501e-02  2.82024816e-02  1.28897414e-01
#  -4.13245196e-03  1.18192598e-01 -2.80175537e-01 -1.06969871e-01]
# size of vector:  300

# %% [markdown]
# # Step4: Get word similarity

# %%
#word1 = '한국'
#word2 = '북한'
print ("Caculate the similarity between word 1 and word2")
word1 = input("word1: ")
word2 = input("word2: ")

# check the words are in the vocabulary
no_problem = True
vocab = model.wv.index_to_key

if word1 not in vocab:
	print ('the word ' + word1 + ' is not in the vocabulary')
	no_problem = False

if word2 not in vocab:
	print ('the word ' + word2 + ' is not in the vocabulary')
	no_problem = False

if no_problem:
	similarity = model.wv.similarity(word1, word2)
	print ('the similarity between ' + word1 + ' and ' + word2 + ' : ', similarity)
# Out:
# Caculate the similarity between word 1 and word2
# word1: 한국
# word2: 북한
# the similarity between 한국 and 북한 :  0.28036028

# %% [markdown]
# # Step5: Find mismatch word

# %%
#words = '소프트웨어 네트워크 프로그램 가방'
print("Find mismatched word in the words")
text = input("text(words): ")
words = text.split()

# check the words are in the vocabulary
no_problem = True
vocab = model.wv.index_to_key

for word in words:
	if word not in vocab:
		print('the word ' + word + ' is not in the vocabulary')
		no_problem = False
		break;

if no_problem:
	mismatched = model.wv.doesnt_match(words)
	print ('the mismatch word between ' + text +' is', mismatched)
# Out:
# Find mismatched word in the words
# text(words): 소프트웨어 네트워크 프로그램 가방
# the mismatch word between 소프트웨어 네트워크 프로그램 가방 is 가방

# %% [markdown]
# # Step 6. Find the top-N most similar words

# %%
print("Print the most similar words")
word = input("word: ")

no_problem = True
vocab = model.wv.index_to_key

if word not in vocab:
	print ('the word ' + word + ' is not in the vocabulary')
	no_problem = False

if no_problem:
    print(model.wv.most_similar(positive=[word]))
# Out:
# Print the most similar words
# word: 인간
# [('동물', 0.617953896522522), ('배아', 0.6104809641838074), ('생쥐', 0.5970973968505859), ('존엄성', 0.5852876901626587), ('본성', 0.5809779167175293), ('인류', 0.5760883092880249), ('생명체', 0.5717364549636841), ('유기체', 0.5703120827674866), ('핵이식', 0.5635316371917725), ('욕망', 0.561828076839447)]

# %% [markdown]
# # Step 7: Vector calculation

# %%
#word_a = '한국'
#word_b = '아시아'
#word_c = '유럽'
print('Find the most similar word with the result of [ a - b + c ]')
word_a = input("a: ")
word_b = input("b: ")
word_c = input("c: ")

# check the words are in the vocabulary
no_problem = True
vocab = model.wv.index_to_key

if word_a not in vocab:
	print ('the word ' + word_a + ' is not in the vocabulary')
	no_problem = False

if word_b not in vocab:
	print ('the word ' + word_b + ' is not in the vocabulary')
	no_problem = False

if word_c not in vocab:
	print ('the word ' + word_c + ' is not in the vocabulary')
	no_problem = False

if no_problem:
	mostsimilar = model.wv.most_similar(positive=[word_a, word_c], negative=[word_b], topn=5)
	print ('most similar word of ' + word_a + ' - ' + word_b + ' + ' + word_c + ' is', mostsimilar[0][0], mostsimilar[1][0], mostsimilar[2][0])
# Out:
# Find the most similar word with the result of [ a - b + c ]
# a: 독도
# b: 한국
# c: 일본
# most similar word of 독도 - 한국 + 일본 is 다케시마 영유권 울릉도
