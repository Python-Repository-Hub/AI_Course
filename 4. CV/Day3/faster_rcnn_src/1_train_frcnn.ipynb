# %%
import random
import pprint
import sys
import time
import numpy as np
from optparse import OptionParser
import pickle
import os

import tensorflow as tf
from keras import backend as K
from keras.optimizers import Adam, SGD, RMSprop
from keras.layers import Input
from keras.models import Model
from keras_frcnn import config, data_generators
from keras_frcnn import losses as losses
import keras_frcnn.roi_helpers as roi_helpers
from keras.utils import generic_utils
from keras_frcnn import vgg as nn
from keras_frcnn.pascal_voc_parser import get_data

# %%
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
sys.setrecursionlimit(40000) #재귀함수 한도 증가

# %%
train_path = "./dataset/VOCdevkit"
config_output_filename ="./config_file/config.pickle"

# num_epochs=10
num_epochs=100

C = config.Config()
C.use_horizontal_flips = False
C.use_vertical_flips = False
C.rot_90 = False
C.model_path = './config_file/model_frcnn.hdf5'
C.num_rois = 32
C.network = 'vgg'
C.base_net_weights = "./config_file/"+nn.get_weight_path()

# %% [markdown]
# ## 데이터셋 다운로드

# %% [markdown]
# VOC 2012 : http://host.robots.ox.ac.uk/pascal/VOC/voc2012/
#
# 총 20가지 class. Classification, Object detection, Segementaion을 성능 측정을 위한 정보 제공
#
# - 사람 : 사람
#
# - 동물 : 새, 고양이, 소, 개, 말, 양
#
# - 탈것 : 비행기, 자전거, 보트, 버스, 승용차, 오토바이, 기차
#
# - 사물 : 병, 의자, 식탁, 화초, 소파, 모니터

# %%
if not os.path.exists(train_path):
#     !wget http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar -P ./dataset
    # !tar -xvf ./dataset/VOCtrainval_11-May-2012.tar -C ./dataset

# %%
# xml 파일 parsing
all_imgs, classes_count, class_mapping = get_data(train_path)

# background 클래스 추가
if 'bg' not in classes_count:
    classes_count['bg'] = 0
    class_mapping['bg'] = len(class_mapping)

C.class_mapping = class_mapping
C.classes_count = classes_count

inv_map = {v: k for k, v in class_mapping.items()}
print('Training images per class:')
pprint.pprint(classes_count)
print('Num classes (including bg) = {}'.format(len(classes_count)))
# Out:
# Parsing annotation files
# Training images per class:
# {'aeroplane': 954,
#  'bg': 0,
#  'bicycle': 790,
#  'bird': 1221,
#  'boat': 999,
#  'bottle': 1482,
#  'bus': 637,
#  'car': 2364,
#  'cat': 1227,
#  'chair': 2906,
#  'cow': 702,
#  'diningtable': 747,
#  'dog': 1541,
#  'horse': 750,
#  'motorbike': 751,
#  'person': 10129,
#  'pottedplant': 1099,
#  'sheep': 994,
#  'sofa': 786,
#  'train': 656,
#  'tvmonitor': 826}
# Num classes (including bg) = 21

# %% [markdown]
# ### 설정값 저장

# %%
with open(config_output_filename, 'wb') as config_f:
    pickle.dump(C, config_f)
    print('Config has been written to {}, and can be loaded when testing to ensure correct results'.format(config_output_filename))
# Out:
# Config has been written to ./config_file/config.pickle, and can be loaded when testing to ensure correct results

# %% [markdown]
# ### 데이터 분류

# %%
random.shuffle(all_imgs)
num_imgs = len(all_imgs)

train_imgs = [s for s in all_imgs if s['imageset'] == 'train']
val_imgs = [s for s in all_imgs if s['imageset'] == 'val']
test_imgs = [s for s in all_imgs if s['imageset'] == 'test']

print('Num train samples {}'.format(len(train_imgs)))
print('Num val samples {}'.format(len(val_imgs)))
print('Num test samples {}'.format(len(test_imgs)))
# Out:
# Num train samples 5717
# Num val samples 5823
# Num test samples 0

# %%
# groundtruth anchor 데이터 가져오기
data_gen_train = data_generators.get_anchor_gt(train_imgs, classes_count, C, nn.get_img_output_length, K.image_data_format(), mode='train')
data_gen_val = data_generators.get_anchor_gt(val_imgs, classes_count, C, nn.get_img_output_length, K.image_data_format(), mode='val')
data_gen_test = data_generators.get_anchor_gt(test_imgs, classes_count, C, nn.get_img_output_length, K.image_data_format(), mode='val')

input_shape_img = (None, None, 3)

# input placeholder 정의
img_input = Input(shape=input_shape_img)
roi_input = Input(shape=(None, 4))

# %%
# base network(feature extractor) 정의
from keras_frcnn import vgg as nn_base
shared_layers = nn.nn_base(img_input, trainable=True)

# %%
# define the RPN, built on the base layers
# RPN 정의
num_anchors = len(C.anchor_box_scales) * len(C.anchor_box_ratios)
rpn = nn.rpn(shared_layers, num_anchors)

# detection network 정의
classifier = nn.classifier(shared_layers, roi_input, C.num_rois, nb_classes=len(classes_count), trainable=True)

model_rpn = Model(img_input, rpn[:2])
model_classifier = Model([img_input, roi_input], classifier)

# this is a model that holds both the RPN and the classifier, used to load/save weights for the models
model_all = Model([img_input, roi_input], rpn[:2] + classifier)

if not os.path.exists(C.base_net_weights):
    # !wget https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5  -P ./config_file

print('loading weights from {}'.format(C.base_net_weights))
model_rpn.load_weights(C.base_net_weights, by_name=True)
model_classifier.load_weights(C.base_net_weights, by_name=True)
# Out:
# loading weights from ./config_file/vgg16_weights_tf_dim_ordering_tf_kernels.h5

# %%
optimizer = Adam(lr=1e-5)
optimizer_classifier = Adam(lr=1e-5)
model_rpn.compile(optimizer=optimizer, loss=[losses.rpn_loss_cls(num_anchors), losses.rpn_loss_regr(num_anchors)])
model_classifier.compile(optimizer=optimizer_classifier, loss=[losses.class_loss_cls, losses.class_loss_regr(len(classes_count)-1)], metrics={'dense_class_{}'.format(len(classes_count)): 'accuracy'})
model_all.compile(optimizer='sgd', loss='mae')

# %%
model_all.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, None, None, 6 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, None, None, 6 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, None, None, 6 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, None, None, 1 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, None, None, 1 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, None, None, 1 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, None, None, 2 295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, None, None, 2 590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, None, None, 2 590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, None, None, 2 0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, None, None, 5 1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, None, None, 5 2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, None, None, 5 2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, None, None, 5 0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, None, None, 5 2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, None, None, 5 2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, None, None, 5 2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None, 4)]    0
# __________________________________________________________________________________________________
# roiPool (RoiPoolingConv)        (1, 32, 7, 7, 512)   0           block5_conv3[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# td1 (TimeDistributed)           (1, 32, 25088)       0           roiPool[0][0]
# __________________________________________________________________________________________________
# td2 (TimeDistributed)           (1, 32, 4096)        102764544   td1[0][0]
# __________________________________________________________________________________________________
# rpn_conv1 (Conv2D)              (None, None, None, 2 1179904     block5_conv3[0][0]
# __________________________________________________________________________________________________
# td3 (TimeDistributed)           (1, 32, 4096)        16781312    td2[0][0]
# __________________________________________________________________________________________________
# rpn_out_class (Conv2D)          (None, None, None, 9 2313        rpn_conv1[0][0]
# __________________________________________________________________________________________________
# rpn_out_regress (Conv2D)        (None, None, None, 3 9252        rpn_conv1[0][0]
# __________________________________________________________________________________________________
# dense_class_21 (TimeDistributed (1, 32, 21)          86037       td3[0][0]
# __________________________________________________________________________________________________
# dense_regress_21 (TimeDistribut (1, 32, 80)          327760      td3[0][0]
# ==================================================================================================
# Total params: 135,865,810
# Trainable params: 135,865,810
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %matplotlib inline

SVG(model_to_dot(model_all, show_shapes=True).create(prog='dot', format='svg'))

# %%
epoch_length = 1000
num_epochs = int(num_epochs)
iter_num = 0
train_step = 0

losses = np.zeros((epoch_length, 5))
rpn_accuracy_rpn_monitor = []
rpn_accuracy_for_epoch = []
start_time = time.time()

best_loss = np.Inf

class_mapping_inv = {v: k for k, v in class_mapping.items()}

# %%
for epoch_num in range(num_epochs):

    progbar = generic_utils.Progbar(epoch_length)   # keras progress bar 사용
    print('Epoch {}/{}'.format(epoch_num + 1, num_epochs))

    while True:
        # try:
        # mean overlapping bboxes 출력
        if len(rpn_accuracy_rpn_monitor) == epoch_length and C.verbose:
            mean_overlapping_bboxes = float(sum(rpn_accuracy_rpn_monitor))/len(rpn_accuracy_rpn_monitor)
            rpn_accuracy_rpn_monitor = []
            print('Average number of overlapping bounding boxes from RPN = {} for {} previous iterations'.format(mean_overlapping_bboxes, epoch_length))
            if mean_overlapping_bboxes == 0:
                print('RPN is not producing bounding boxes that overlap the ground truth boxes. Check RPN settings or keep training.')

        # data generator에서 X, Y, image 가져오기
        X, Y, img_data = next(data_gen_train)

        loss_rpn = model_rpn.train_on_batch(X, Y)

        P_rpn = model_rpn.predict_on_batch(X)

        R = roi_helpers.rpn_to_roi(P_rpn[0], P_rpn[1], C, K.image_data_format(), use_regr=True, overlap_thresh=0.7, max_boxes=300)
        # note: calc_iou converts from (x1,y1,x2,y2) to (x,y,w,h) format
        X2, Y1, Y2, IouS = roi_helpers.calc_iou(R, img_data, C, class_mapping)

        if X2 is None:
            rpn_accuracy_rpn_monitor.append(0)
            rpn_accuracy_for_epoch.append(0)
            continue

        # sampling positive/negative samples
        neg_samples = np.where(Y1[0, :, -1] == 1)
        pos_samples = np.where(Y1[0, :, -1] == 0)

        if len(neg_samples) > 0:
            neg_samples = neg_samples[0]
        else:
            neg_samples = []

        if len(pos_samples) > 0:
            pos_samples = pos_samples[0]
        else:
            pos_samples = []

        rpn_accuracy_rpn_monitor.append(len(pos_samples))
        rpn_accuracy_for_epoch.append((len(pos_samples)))

        if C.num_rois > 1:
            if len(pos_samples) < C.num_rois//2:
                selected_pos_samples = pos_samples.tolist()
            else:
                selected_pos_samples = np.random.choice(pos_samples, C.num_rois//2, replace=False).tolist()
            try:
                selected_neg_samples = np.random.choice(neg_samples, C.num_rois - len(selected_pos_samples), replace=False).tolist()
            except:
                selected_neg_samples = np.random.choice(neg_samples, C.num_rois - len(selected_pos_samples), replace=True).tolist()

            sel_samples = selected_pos_samples + selected_neg_samples
        else:
            # in the extreme case where num_rois = 1, we pick a random pos or neg sample
            selected_pos_samples = pos_samples.tolist()
            selected_neg_samples = neg_samples.tolist()
            if np.random.randint(0, 2):
                sel_samples = random.choice(neg_samples)
            else:
                sel_samples = random.choice(pos_samples)

        loss_class = model_classifier.train_on_batch([X, X2[:, sel_samples, :]], [Y1[:, sel_samples, :], Y2[:, sel_samples, :]])
        

        losses[iter_num, 0] = loss_rpn[1]
        losses[iter_num, 1] = loss_rpn[2]

        losses[iter_num, 2] = loss_class[1]
        losses[iter_num, 3] = loss_class[2]
        losses[iter_num, 4] = loss_class[3]

        iter_num += 1

        progbar.update(iter_num, [('rpn_cls', np.mean(losses[:iter_num, 0])), ('rpn_regr', np.mean(losses[:iter_num, 1])),
                                  ('detector_cls', np.mean(losses[:iter_num, 2])), ('detector_regr', np.mean(losses[:iter_num, 3]))])

        if iter_num == epoch_length:
            loss_rpn_cls = np.mean(losses[:, 0])
            loss_rpn_regr = np.mean(losses[:, 1])
            loss_class_cls = np.mean(losses[:, 2])
            loss_class_regr = np.mean(losses[:, 3])
            class_acc = np.mean(losses[:, 4])

            mean_overlapping_bboxes = float(sum(rpn_accuracy_for_epoch)) / len(rpn_accuracy_for_epoch)
            rpn_accuracy_for_epoch = []

            if C.verbose:
                print('Mean number of bounding boxes from RPN overlapping ground truth boxes: {}'.format(mean_overlapping_bboxes))
                print('Classifier accuracy for bounding boxes from RPN: {}'.format(class_acc))
                print('Loss RPN classifier: {}'.format(loss_rpn_cls))
                print('Loss RPN regression: {}'.format(loss_rpn_regr))
                print('Loss Detector classifier: {}'.format(loss_class_cls))
                print('Loss Detector regression: {}'.format(loss_class_regr))
                print('Elapsed time: {}'.format(time.time() - start_time))

            curr_loss = loss_rpn_cls + loss_rpn_regr + loss_class_cls + loss_class_regr
            iter_num = 0
            start_time = time.time()


            if curr_loss < best_loss:
                if C.verbose:
                    print('Total loss decreased from {} to {}, saving weights'.format(best_loss,curr_loss))
                best_loss = curr_loss
                model_all.save_weights(C.model_path)

            break

print('Training complete, exiting.')
# Out:
# Epoch 1/100
# 1000/1000 [==============================] - 799s 799ms/step - rpn_cls: 2.2778 - rpn_regr: 0.2071 - detector_cls: 1.0101 - detector_regr: 0.3847
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 14.207
# Classifier accuracy for bounding boxes from RPN: 0.68725
# Loss RPN classifier: 2.3463598574143236
# Loss RPN regression: 0.20421906087780373
# Loss Detector classifier: 0.988461229747627
# Loss Detector regression: 0.37194471492618325
# Elapsed time: 799.6605467796326
# Total loss decreased from 5.061125786624163 to 3.910984862965938, saving weights
# Epoch 3/100
# Average number of overlapping bounding boxes from RPN = 14.207 for 1000 previous iterations
# 1000/1000 [==============================] - 744s 744ms/step - rpn_cls: 2.3094 - rpn_regr: 0.2002 - detector_cls: 0.9416 - detector_regr: 0.3618
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 15.629
# Classifier accuracy for bounding boxes from RPN: 0.68759375
# Loss RPN classifier: 2.240933199021003
# Loss RPN regression: 0.1891793316807598
# Loss Detector classifier: 0.9180120521448553
# Loss Detector regression: 0.35068207667768003
# Elapsed time: 745.0274765491486
# Total loss decreased from 3.910984862965938 to 3.698806659524298, saving weights
# Epoch 4/100
# Average number of overlapping bounding boxes from RPN = 15.629 for 1000 previous iterations
# 1000/1000 [==============================] - 675s 675ms/step - rpn_cls: 2.0296 - rpn_regr: 0.1789 - detector_cls: 0.8793 - detector_regr: 0.3271
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 15.129
# Classifier accuracy for bounding boxes from RPN: 0.70340625
# Loss RPN classifier: 2.109945100226537
# Loss RPN regression: 0.18027142426930368
# Loss Detector classifier: 0.8574488893400412
# Loss Detector regression: 0.3263785191848874
# Elapsed time: 675.828027009964
# Total loss decreased from 3.698806659524298 to 3.4740439330207695, saving weights
# Epoch 5/100
# Average number of overlapping bounding boxes from RPN = 15.129 for 1000 previous iterations
#   80/1000 [=>............................] - ETA: 9:23 - rpn_cls: 1.5718 - rpn_regr: 0.1585 - detector_cls: 0.6667 - detector_regr: 0.3332
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 2.0978 - rpn_regr: 0.1838 - detector_cls: 0.7917 - detector_regr: 0.3098Average number of overlapping bounding boxes from RPN = 16.104 for 1000 previous iterations
# 1000/1000 [==============================] - 593s 593ms/step - rpn_cls: 2.0977 - rpn_regr: 0.1838 - detector_cls: 0.7917 - detector_regr: 0.3098
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 16.099
# Classifier accuracy for bounding boxes from RPN: 0.725125
# Loss RPN classifier: 1.9383441253205935
# Loss RPN regression: 0.18307128224428743
# Loss Detector classifier: 0.7701868018533569
# Loss Detector regression: 0.3032703430764377
# Elapsed time: 594.4282512664795
# Total loss decreased from 3.3702703603206885 to 3.1948725524946755, saving weights
# Epoch 7/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.7708 - rpn_regr: 0.1809 - detector_cls: 0.7385 - detector_regr: 0.2910Average number of overlapping bounding boxes from RPN = 16.95 for 1000 previous iterations
# 1000/1000 [==============================] - 491s 491ms/step - rpn_cls: 1.7707 - rpn_regr: 0.1809 - detector_cls: 0.7385 - detector_regr: 0.2910
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 16.948
# Classifier accuracy for bounding boxes from RPN: 0.7295
# Loss RPN classifier: 1.6825090042938977
# Loss RPN regression: 0.1719217297937721
# Loss Detector classifier: 0.7449157790914178
# Loss Detector regression: 0.2896682540848851
# Elapsed time: 491.63669061660767
# Total loss decreased from 3.1948725524946755 to 2.8890147672639723, saving weights
# Epoch 8/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.6688 - rpn_regr: 0.1844 - detector_cls: 0.6974 - detector_regr: 0.2792Average number of overlapping bounding boxes from RPN = 17.016 for 1000 previous iterations
# 1000/1000 [==============================] - 499s 499ms/step - rpn_cls: 1.6688 - rpn_regr: 0.1844 - detector_cls: 0.6974 - detector_regr: 0.2792
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 17.022
# Classifier accuracy for bounding boxes from RPN: 0.74371875
# Loss RPN classifier: 1.7030566010126276
# Loss RPN regression: 0.1838571536343079
# Loss Detector classifier: 0.6917472657635808
# Loss Detector regression: 0.2821119233369827
# Elapsed time: 500.50474524497986
# Total loss decreased from 2.8890147672639723 to 2.860772943747499, saving weights
# Epoch 9/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.7244 - rpn_regr: 0.1724 - detector_cls: 0.7012 - detector_regr: 0.2839Average number of overlapping bounding boxes from RPN = 16.91 for 1000 previous iterations
# 1000/1000 [==============================] - 487s 487ms/step - rpn_cls: 1.7244 - rpn_regr: 0.1724 - detector_cls: 0.7012 - detector_regr: 0.2839
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 16.906
# Classifier accuracy for bounding boxes from RPN: 0.74753125
# Loss RPN classifier: 1.7254508161368245
# Loss RPN regression: 0.1689241314623505
# Loss Detector classifier: 0.6996689967252314
# Loss Detector regression: 0.27796403935551645
# Elapsed time: 488.2560293674469
# Epoch 10/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.6787 - rpn_regr: 0.1556 - detector_cls: 0.6629 - detector_regr: 0.2771Average number of overlapping bounding boxes from RPN = 16.811 for 1000 previous iterations
# 1000/1000 [==============================] - 487s 487ms/step - rpn_cls: 1.6787 - rpn_regr: 0.1556 - detector_cls: 0.6629 - detector_regr: 0.2771
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 16.811
# Classifier accuracy for bounding boxes from RPN: 0.7504375
# Loss RPN classifier: 1.6727476434457664
# Loss RPN regression: 0.1668684327332303
# Loss Detector classifier: 0.6814632299924269
# Loss Detector regression: 0.27807867572456596
# Elapsed time: 486.6388671398163
# Total loss decreased from 2.860772943747499 to 2.7991579818959895, saving weights
# Epoch 11/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.7609 - rpn_regr: 0.1722 - detector_cls: 0.6712 - detector_regr: 0.2721Average number of overlapping bounding boxes from RPN = 17.106 for 1000 previous iterations
# 1000/1000 [==============================] - 498s 498ms/step - rpn_cls: 1.7608 - rpn_regr: 0.1722 - detector_cls: 0.6712 - detector_regr: 0.2721
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 17.112
# Classifier accuracy for bounding boxes from RPN: 0.755375
# Loss RPN classifier: 1.7158492501178986
# Loss RPN regression: 0.1755713933734223
# Loss Detector classifier: 0.6798913835724816
# Loss Detector regression: 0.2699837446175516
# Elapsed time: 498.8572735786438
# Epoch 12/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.5059 - rpn_regr: 0.1837 - detector_cls: 0.6887 - detector_regr: 0.2734Average number of overlapping bounding boxes from RPN = 17.55 for 1000 previous iterations
# 1000/1000 [==============================] - 487s 487ms/step - rpn_cls: 1.5059 - rpn_regr: 0.1837 - detector_cls: 0.6886 - detector_regr: 0.2734
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 17.56
# Classifier accuracy for bounding boxes from RPN: 0.76121875
# Loss RPN classifier: 1.509868034074275
# Loss RPN regression: 0.17544989745039494
# Loss Detector classifier: 0.6503734922464937
# Loss Detector regression: 0.26043410006165507
# Elapsed time: 486.5695376396179
# Total loss decreased from 2.7991579818959895 to 2.5961255238328187, saving weights
# Epoch 13/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.3517 - rpn_regr: 0.1638 - detector_cls: 0.5937 - detector_regr: 0.2446Average number of overlapping bounding boxes from RPN = 17.862 for 1000 previous iterations
# 1000/1000 [==============================] - 486s 486ms/step - rpn_cls: 1.3517 - rpn_regr: 0.1638 - detector_cls: 0.5937 - detector_regr: 0.2446
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 17.865
# Classifier accuracy for bounding boxes from RPN: 0.7754375
# Loss RPN classifier: 1.4126091270604983
# Loss RPN regression: 0.16913618908636271
# Loss Detector classifier: 0.594960210621357
# Loss Detector regression: 0.2485864605959505
# Elapsed time: 487.1278796195984
# Total loss decreased from 2.5961255238328187 to 2.4252919873641687, saving weights
# Epoch 14/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.3959 - rpn_regr: 0.1611 - detector_cls: 0.5785 - detector_regr: 0.2445Average number of overlapping bounding boxes from RPN = 17.771 for 1000 previous iterations
# 1000/1000 [==============================] - 484s 484ms/step - rpn_cls: 1.3958 - rpn_regr: 0.1611 - detector_cls: 0.5785 - detector_regr: 0.2445
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 17.758
# Classifier accuracy for bounding boxes from RPN: 0.78425
# Loss RPN classifier: 1.3381410324764376
# Loss RPN regression: 0.16480403985083103
# Loss Detector classifier: 0.5817353533692657
# Loss Detector regression: 0.24455296847596764
# Elapsed time: 484.852068901062
# Total loss decreased from 2.4252919873641687 to 2.329233394172502, saving weights
# Epoch 15/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.4086 - rpn_regr: 0.1652 - detector_cls: 0.5926 - detector_regr: 0.2486Average number of overlapping bounding boxes from RPN = 17.347 for 1000 previous iterations
# 1000/1000 [==============================] - 491s 491ms/step - rpn_cls: 1.4086 - rpn_regr: 0.1652 - detector_cls: 0.5926 - detector_regr: 0.2486
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 17.341
# Classifier accuracy for bounding boxes from RPN: 0.774875
# Loss RPN classifier: 1.3751399446253318
# Loss RPN regression: 0.16966569957509636
# Loss Detector classifier: 0.6074989881068468
# Loss Detector regression: 0.24894904884696006
# Elapsed time: 491.79679822921753
# Epoch 16/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.4804 - rpn_regr: 0.1731 - detector_cls: 0.5922 - detector_regr: 0.2471Average number of overlapping bounding boxes from RPN = 16.833 for 1000 previous iterations
# 1000/1000 [==============================] - 479s 479ms/step - rpn_cls: 1.4804 - rpn_regr: 0.1731 - detector_cls: 0.5922 - detector_regr: 0.2471
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 16.841
# Classifier accuracy for bounding boxes from RPN: 0.77978125
# Loss RPN classifier: 1.4688458561695235
# Loss RPN regression: 0.16621796346548945
# Loss Detector classifier: 0.5913581243748777
# Loss Detector regression: 0.24402248548343777
# Elapsed time: 479.20460987091064
# Epoch 17/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.4249 - rpn_regr: 0.1611 - detector_cls: 0.6359 - detector_regr: 0.2593Average number of overlapping bounding boxes from RPN = 18.317 for 1000 previous iterations
# 1000/1000 [==============================] - 484s 484ms/step - rpn_cls: 1.4249 - rpn_regr: 0.1611 - detector_cls: 0.6359 - detector_regr: 0.2593
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.311
# Classifier accuracy for bounding boxes from RPN: 0.77265625
# Loss RPN classifier: 1.437413379283424
# Loss RPN regression: 0.16490607238560914
# Loss Detector classifier: 0.615363902659621
# Loss Detector regression: 0.2517609439752996
# Elapsed time: 484.3159372806549
# Epoch 18/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.2864 - rpn_regr: 0.1573 - detector_cls: 0.5838 - detector_regr: 0.2350Average number of overlapping bounding boxes from RPN = 17.68 for 1000 previous iterations
# 1000/1000 [==============================] - 486s 486ms/step - rpn_cls: 1.2863 - rpn_regr: 0.1573 - detector_cls: 0.5838 - detector_regr: 0.2350
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 17.683
# Classifier accuracy for bounding boxes from RPN: 0.79715625
# Loss RPN classifier: 1.211727976386941
# Loss RPN regression: 0.16020731025980786
# Loss Detector classifier: 0.5390535713043064
# Loss Detector regression: 0.22697503902204336
# Elapsed time: 485.7519733905792
# Total loss decreased from 2.329233394172502 to 2.1379638969730985, saving weights
# Epoch 19/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.2651 - rpn_regr: 0.1682 - detector_cls: 0.5096 - detector_regr: 0.2304Average number of overlapping bounding boxes from RPN = 18.673 for 1000 previous iterations
# 1000/1000 [==============================] - 483s 483ms/step - rpn_cls: 1.2650 - rpn_regr: 0.1682 - detector_cls: 0.5096 - detector_regr: 0.2304
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.7
# Classifier accuracy for bounding boxes from RPN: 0.80009375
# Loss RPN classifier: 1.2069059783886806
# Loss RPN regression: 0.15604113865550606
# Loss Detector classifier: 0.5112362788417376
# Loss Detector regression: 0.22703749669715761
# Elapsed time: 483.7686641216278
# Total loss decreased from 2.1379638969730985 to 2.101220892583082, saving weights
# Epoch 20/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.1947 - rpn_regr: 0.1718 - detector_cls: 0.5317 - detector_regr: 0.2222Average number of overlapping bounding boxes from RPN = 18.697 for 1000 previous iterations
# 1000/1000 [==============================] - 485s 485ms/step - rpn_cls: 1.1947 - rpn_regr: 0.1718 - detector_cls: 0.5317 - detector_regr: 0.2222
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.667
# Classifier accuracy for bounding boxes from RPN: 0.79734375
# Loss RPN classifier: 1.2105624229605492
# Loss RPN regression: 0.171120208641747
# Loss Detector classifier: 0.5288125350205227
# Loss Detector regression: 0.2249193892683834
# Elapsed time: 485.89935874938965
# Epoch 21/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.3635 - rpn_regr: 0.1615 - detector_cls: 0.5209 - detector_regr: 0.2216Average number of overlapping bounding boxes from RPN = 17.557 for 1000 previous iterations
# 1000/1000 [==============================] - 482s 482ms/step - rpn_cls: 1.3635 - rpn_regr: 0.1615 - detector_cls: 0.5209 - detector_regr: 0.2216
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 17.577
# Classifier accuracy for bounding boxes from RPN: 0.80140625
# Loss RPN classifier: 1.3397754368854349
# Loss RPN regression: 0.16323864485416562
# Loss Detector classifier: 0.5187231721414719
# Loss Detector regression: 0.2191713834926486
# Elapsed time: 481.6825568675995
# Epoch 22/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.1731 - rpn_regr: 0.1514 - detector_cls: 0.5246 - detector_regr: 0.2218Average number of overlapping bounding boxes from RPN = 17.966 for 1000 previous iterations
# 1000/1000 [==============================] - 478s 478ms/step - rpn_cls: 1.1731 - rpn_regr: 0.1514 - detector_cls: 0.5246 - detector_regr: 0.2218
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 17.936
# Classifier accuracy for bounding boxes from RPN: 0.80190625
# Loss RPN classifier: 1.149006462550313
# Loss RPN regression: 0.15419128543511032
# Loss Detector classifier: 0.5255983618926257
# Loss Detector regression: 0.21833108045719565
# Elapsed time: 477.64161014556885
# Total loss decreased from 2.101220892583082 to 2.0471271903352446, saving weights
# Epoch 23/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.2681 - rpn_regr: 0.1652 - detector_cls: 0.5406 - detector_regr: 0.2256Average number of overlapping bounding boxes from RPN = 18.452 for 1000 previous iterations
# 1000/1000 [==============================] - 489s 489ms/step - rpn_cls: 1.2680 - rpn_regr: 0.1652 - detector_cls: 0.5406 - detector_regr: 0.2256
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.455
# Classifier accuracy for bounding boxes from RPN: 0.80090625
# Loss RPN classifier: 1.2443724822439317
# Loss RPN regression: 0.1621528557690326
# Loss Detector classifier: 0.5229350803345442
# Loss Detector regression: 0.22173051708005367
# Elapsed time: 490.5736970901489
# Epoch 24/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 0.9502 - rpn_regr: 0.1506 - detector_cls: 0.4451 - detector_regr: 0.1955Average number of overlapping bounding boxes from RPN = 18.623 for 1000 previous iterations
# 1000/1000 [==============================] - 478s 478ms/step - rpn_cls: 0.9503 - rpn_regr: 0.1506 - detector_cls: 0.4452 - detector_regr: 0.1955
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.63
# Classifier accuracy for bounding boxes from RPN: 0.82446875
# Loss RPN classifier: 1.034944552930018
# Loss RPN regression: 0.1523564804366324
# Loss Detector classifier: 0.4507836988857016
# Loss Detector regression: 0.20514199780113995
# Elapsed time: 478.1380214691162
# Total loss decreased from 2.0471271903352446 to 1.8432267300534921, saving weights
# Epoch 25/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.1414 - rpn_regr: 0.1556 - detector_cls: 0.4815 - detector_regr: 0.2074Average number of overlapping bounding boxes from RPN = 18.62 for 1000 previous iterations
# 1000/1000 [==============================] - 488s 488ms/step - rpn_cls: 1.1413 - rpn_regr: 0.1556 - detector_cls: 0.4815 - detector_regr: 0.2074
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.62
# Classifier accuracy for bounding boxes from RPN: 0.81915625
# Loss RPN classifier: 1.0516816218482055
# Loss RPN regression: 0.15788053874950855
# Loss Detector classifier: 0.46334374916553495
# Loss Detector regression: 0.20219697461463512
# Elapsed time: 488.9232165813446
# Epoch 26/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.0363 - rpn_regr: 0.1682 - detector_cls: 0.4585 - detector_regr: 0.1992Average number of overlapping bounding boxes from RPN = 17.944 for 1000 previous iterations
# 1000/1000 [==============================] - 481s 481ms/step - rpn_cls: 1.0363 - rpn_regr: 0.1682 - detector_cls: 0.4585 - detector_regr: 0.1992
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 17.96
# Classifier accuracy for bounding boxes from RPN: 0.82425
# Loss RPN classifier: 1.0155614930052836
# Loss RPN regression: 0.16237657085666432
# Loss Detector classifier: 0.45860388297587634
# Loss Detector regression: 0.20111063761310652
# Elapsed time: 481.497465133667
# Total loss decreased from 1.8432267300534921 to 1.8376525844509306, saving weights
# Epoch 27/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.0513 - rpn_regr: 0.1580 - detector_cls: 0.4902 - detector_regr: 0.2135Average number of overlapping bounding boxes from RPN = 17.677 for 1000 previous iterations
# 1000/1000 [==============================] - 482s 482ms/step - rpn_cls: 1.0513 - rpn_regr: 0.1580 - detector_cls: 0.4901 - detector_regr: 0.2135
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 17.662
# Classifier accuracy for bounding boxes from RPN: 0.81353125
# Loss RPN classifier: 1.0913335615017654
# Loss RPN regression: 0.16151665471587331
# Loss Detector classifier: 0.47855357952136546
# Loss Detector regression: 0.20615879208035767
# Elapsed time: 482.89489006996155
# Epoch 28/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.0788 - rpn_regr: 0.1570 - detector_cls: 0.4802 - detector_regr: 0.2106Average number of overlapping bounding boxes from RPN = 18.802 for 1000 previous iterations
# 1000/1000 [==============================] - 482s 482ms/step - rpn_cls: 1.0787 - rpn_regr: 0.1570 - detector_cls: 0.4802 - detector_regr: 0.2106
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.814
# Classifier accuracy for bounding boxes from RPN: 0.819375
# Loss RPN classifier: 1.0474046343932473
# Loss RPN regression: 0.1599467691075988
# Loss Detector classifier: 0.4651886732939165
# Loss Detector regression: 0.20549544326029717
# Elapsed time: 481.63670468330383
# Epoch 29/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.0374 - rpn_regr: 0.1511 - detector_cls: 0.4835 - detector_regr: 0.2009Average number of overlapping bounding boxes from RPN = 19.607 for 1000 previous iterations
# 1000/1000 [==============================] - 487s 487ms/step - rpn_cls: 1.0373 - rpn_regr: 0.1511 - detector_cls: 0.4834 - detector_regr: 0.2009
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.618
# Classifier accuracy for bounding boxes from RPN: 0.82315625
# Loss RPN classifier: 0.9986702985099236
# Loss RPN regression: 0.15518056641938166
# Loss Detector classifier: 0.4522032797077045
# Loss Detector regression: 0.1943843693267554
# Elapsed time: 487.42418789863586
# Total loss decreased from 1.8376525844509306 to 1.800438513963765, saving weights
# Epoch 30/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 0.9283 - rpn_regr: 0.1514 - detector_cls: 0.4052 - detector_regr: 0.1783Average number of overlapping bounding boxes from RPN = 18.974 for 1000 previous iterations
# 1000/1000 [==============================] - 484s 484ms/step - rpn_cls: 0.9283 - rpn_regr: 0.1514 - detector_cls: 0.4052 - detector_regr: 0.1783
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.949
# Classifier accuracy for bounding boxes from RPN: 0.84059375
# Loss RPN classifier: 0.9008361217397014
# Loss RPN regression: 0.15044668832456226
# Loss Detector classifier: 0.40527689849655146
# Loss Detector regression: 0.18254291980713605
# Elapsed time: 484.8270697593689
# Total loss decreased from 1.800438513963765 to 1.6391026283679513, saving weights
# Epoch 31/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 0.9278 - rpn_regr: 0.1464 - detector_cls: 0.4123 - detector_regr: 0.1835Average number of overlapping bounding boxes from RPN = 18.568 for 1000 previous iterations
# 1000/1000 [==============================] - 478s 478ms/step - rpn_cls: 0.9278 - rpn_regr: 0.1464 - detector_cls: 0.4123 - detector_regr: 0.1835
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.567
# Classifier accuracy for bounding boxes from RPN: 0.8355625
# Loss RPN classifier: 0.8858176616494018
# Loss RPN regression: 0.15426539681386203
# Loss Detector classifier: 0.4151000276305715
# Loss Detector regression: 0.1843282116977498
# Elapsed time: 478.93567967414856
# Epoch 32/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.0075 - rpn_regr: 0.1587 - detector_cls: 0.4369 - detector_regr: 0.1827Average number of overlapping bounding boxes from RPN = 19.145 for 1000 previous iterations
# 1000/1000 [==============================] - 482s 482ms/step - rpn_cls: 1.0075 - rpn_regr: 0.1587 - detector_cls: 0.4370 - detector_regr: 0.1827
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.159
# Classifier accuracy for bounding boxes from RPN: 0.8229375
# Loss RPN classifier: 1.0208177801929639
# Loss RPN regression: 0.16212842531036586
# Loss Detector classifier: 0.44427260279888287
# Loss Detector regression: 0.1908953832872212
# Elapsed time: 481.92826104164124
# Epoch 33/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 0.8774 - rpn_regr: 0.1519 - detector_cls: 0.4375 - detector_regr: 0.1885Average number of overlapping bounding boxes from RPN = 18.815 for 1000 previous iterations
# 1000/1000 [==============================] - 480s 480ms/step - rpn_cls: 0.8775 - rpn_regr: 0.1519 - detector_cls: 0.4375 - detector_regr: 0.1885
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.805
# Classifier accuracy for bounding boxes from RPN: 0.828375
# Loss RPN classifier: 0.9602869377822808
# Loss RPN regression: 0.15201586223952473
# Loss Detector classifier: 0.4342312782238005
# Loss Detector regression: 0.18504672620538623
# Elapsed time: 479.62333583831787
# Epoch 34/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 0.9975 - rpn_regr: 0.1496 - detector_cls: 0.4173 - detector_regr: 0.1900Average number of overlapping bounding boxes from RPN = 19.159 for 1000 previous iterations
# 1000/1000 [==============================] - 478s 478ms/step - rpn_cls: 0.9975 - rpn_regr: 0.1496 - detector_cls: 0.4174 - detector_regr: 0.1900
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.152
# Classifier accuracy for bounding boxes from RPN: 0.83259375
# Loss RPN classifier: 0.9873811855929294
# Loss RPN regression: 0.15364709430886433
# Loss Detector classifier: 0.4196145310085267
# Loss Detector regression: 0.18976260275021195
# Elapsed time: 478.4548759460449
# Epoch 35/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 1.0235 - rpn_regr: 0.1497 - detector_cls: 0.4165 - detector_regr: 0.1830Average number of overlapping bounding boxes from RPN = 18.979 for 1000 previous iterations
# 1000/1000 [==============================] - 479s 479ms/step - rpn_cls: 1.0234 - rpn_regr: 0.1497 - detector_cls: 0.4165 - detector_regr: 0.1830
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.997
# Classifier accuracy for bounding boxes from RPN: 0.839625
# Loss RPN classifier: 0.8975842771666599
# Loss RPN regression: 0.15163759573735297
# Loss Detector classifier: 0.39864555798191575
# Loss Detector regression: 0.1777518425770104
# Elapsed time: 478.6846363544464
# Total loss decreased from 1.6391026283679513 to 1.6256192734629389, saving weights
# Epoch 36/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 0.9193 - rpn_regr: 0.1517 - detector_cls: 0.3789 - detector_regr: 0.1699Average number of overlapping bounding boxes from RPN = 19.155 for 1000 previous iterations
# 1000/1000 [==============================] - 485s 485ms/step - rpn_cls: 0.9192 - rpn_regr: 0.1517 - detector_cls: 0.3789 - detector_regr: 0.1699
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.152
# Classifier accuracy for bounding boxes from RPN: 0.84875
# Loss RPN classifier: 0.8516217851787896
# Loss RPN regression: 0.1562316320957616
# Loss Detector classifier: 0.38044559218827634
# Loss Detector regression: 0.17137808377854527
# Elapsed time: 486.52329993247986
# Total loss decreased from 1.6256192734629389 to 1.5596770932413728, saving weights
# Epoch 37/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 0.8783 - rpn_regr: 0.1464 - detector_cls: 0.3794 - detector_regr: 0.1674Average number of overlapping bounding boxes from RPN = 18.497 for 1000 previous iterations
# 1000/1000 [==============================] - 477s 477ms/step - rpn_cls: 0.8783 - rpn_regr: 0.1465 - detector_cls: 0.3794 - detector_regr: 0.1674
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.505
# Classifier accuracy for bounding boxes from RPN: 0.8488125
# Loss RPN classifier: 0.8977181898779802
# Loss RPN regression: 0.14849054745631293
# Loss Detector classifier: 0.3799089397699572
# Loss Detector regression: 0.1694140297845006
# Elapsed time: 477.785124540329
# Epoch 38/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 0.7836 - rpn_regr: 0.1360 - detector_cls: 0.3603 - detector_regr: 0.1640Average number of overlapping bounding boxes from RPN = 19.84 for 1000 previous iterations
# 1000/1000 [==============================] - 474s 474ms/step - rpn_cls: 0.7836 - rpn_regr: 0.1360 - detector_cls: 0.3603 - detector_regr: 0.1640
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.835
# Classifier accuracy for bounding boxes from RPN: 0.851875
# Loss RPN classifier: 0.8108374392932246
# Loss RPN regression: 0.14510098809050395
# Loss Detector classifier: 0.3769618235332891
# Loss Detector regression: 0.17056726288609206
# Elapsed time: 473.50227332115173
# Total loss decreased from 1.5596770932413728 to 1.50346751380311, saving weights
# Epoch 39/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 0.7583 - rpn_regr: 0.1518 - detector_cls: 0.3872 - detector_regr: 0.1771Average number of overlapping bounding boxes from RPN = 20.001 for 1000 previous iterations
# 1000/1000 [==============================] - 482s 482ms/step - rpn_cls: 0.7583 - rpn_regr: 0.1518 - detector_cls: 0.3872 - detector_regr: 0.1771
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.988
# Classifier accuracy for bounding boxes from RPN: 0.8448125
# Loss RPN classifier: 0.7982191682689053
# Loss RPN regression: 0.15345617624348962
# Loss Detector classifier: 0.38245629756455307
# Loss Detector regression: 0.17504132148250937
# Elapsed time: 483.44008207321167
# Epoch 40/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 0.8664 - rpn_regr: 0.1552 - detector_cls: 0.3994 - detector_regr: 0.1741Average number of overlapping bounding boxes from RPN = 19.156 for 1000 previous iterations
# 1000/1000 [==============================] - 476s 476ms/step - rpn_cls: 0.8664 - rpn_regr: 0.1552 - detector_cls: 0.3995 - detector_regr: 0.1741
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.151
# Classifier accuracy for bounding boxes from RPN: 0.83578125
# Loss RPN classifier: 0.8960028430013033
# Loss RPN regression: 0.15070122531382368
# Loss Detector classifier: 0.41553590630181136
# Loss Detector regression: 0.18235364497173578
# Elapsed time: 476.0445945262909
# Epoch 41/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 0.7925 - rpn_regr: 0.1414 - detector_cls: 0.3492 - detector_regr: 0.1624Average number of overlapping bounding boxes from RPN = 19.474 for 1000 previous iterations
# 1000/1000 [==============================] - 481s 481ms/step - rpn_cls: 0.7925 - rpn_regr: 0.1414 - detector_cls: 0.3492 - detector_regr: 0.1624
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.529
# Classifier accuracy for bounding boxes from RPN: 0.86196875
# Loss RPN classifier: 0.7705554029543669
# Loss RPN regression: 0.14476235754555092
# Loss Detector classifier: 0.34631815292523244
# Loss Detector regression: 0.16304156170319767
# Elapsed time: 480.68077063560486
# Total loss decreased from 1.50346751380311 to 1.424677475128348, saving weights
# Epoch 42/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 0.7846 - rpn_regr: 0.1516 - detector_cls: 0.3393 - detector_regr: 0.1581Average number of overlapping bounding boxes from RPN = 19.455 for 1000 previous iterations
# 1000/1000 [==============================] - 481s 481ms/step - rpn_cls: 0.7846 - rpn_regr: 0.1516 - detector_cls: 0.3393 - detector_regr: 0.1581
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.406
# Classifier accuracy for bounding boxes from RPN: 0.86040625
# Loss RPN classifier: 0.8016378325283957
# Loss RPN regression: 0.15445076800009702
# Loss Detector classifier: 0.34681083287810904
# Loss Detector regression: 0.1586999889574945
# Elapsed time: 481.9416651725769
# Epoch 43/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 0.8138 - rpn_regr: 0.1517 - detector_cls: 0.3538 - detector_regr: 0.1667Average number of overlapping bounding boxes from RPN = 19.155 for 1000 previous iterations
# 1000/1000 [==============================] - 478s 478ms/step - rpn_cls: 0.8138 - rpn_regr: 0.1517 - detector_cls: 0.3538 - detector_regr: 0.1667
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.163
# Classifier accuracy for bounding boxes from RPN: 0.861375
# Loss RPN classifier: 0.7687047524462342
# Loss RPN regression: 0.1459750053519383
# Loss Detector classifier: 0.35376291594374926
# Loss Detector regression: 0.16162167161330582
# Elapsed time: 478.3056945800781
# Epoch 44/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 0.8137 - rpn_regr: 0.1446 - detector_cls: 0.3727 - detector_regr: 0.1659Average number of overlapping bounding boxes from RPN = 19.19 for 1000 previous iterations
# 1000/1000 [==============================] - 476s 476ms/step - rpn_cls: 0.8136 - rpn_regr: 0.1446 - detector_cls: 0.3727 - detector_regr: 0.1659
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.181
# Classifier accuracy for bounding boxes from RPN: 0.85571875
# Loss RPN classifier: 0.7532314901762063
# Loss RPN regression: 0.1438588874307461
# Loss Detector classifier: 0.36133222446171565
# Loss Detector regression: 0.16209687694348396
# Elapsed time: 475.62490797042847
# Total loss decreased from 1.424677475128348 to 1.4205194790121518, saving weights
# Epoch 45/100
#  999/1000 [============================>.] - ETA: 0s - rpn_cls: 0.7475 - rpn_regr: 0.1404 - detector_cls: 0.3464 - detector_regr: 0.1587Average number of overlapping bounding boxes from RPN = 18.646 for 1000 previous iterations
# 1000/1000 [==============================] - 469s 469ms/step - rpn_cls: 0.7475 - rpn_regr: 0.1404 - detector_cls: 0.3464 - detector_regr: 0.1587
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.65
# Classifier accuracy for bounding boxes from RPN: 0.86078125
# Loss RPN classifier: 0.7098938619874796
# Loss RPN regression: 0.142680437842384
# Loss Detector classifier: 0.3511604677157011
# Loss Detector regression: 0.16083414928242565
# Elapsed time: 469.85390305519104
# Total loss decreased from 1.4205194790121518 to 1.3645689168279904, saving weights
# Epoch 46/100
#  998/1000 [============================>.] - ETA: 0s - rpn_cls: 0.7858 - rpn_regr: 0.1495 - detector_cls: 0.3616 - detector_regr: 0.1601Average number of overlapping bounding boxes from RPN = 19.878 for 1000 previous iterations
# 1000/1000 [==============================] - 477s 477ms/step - rpn_cls: 0.7858 - rpn_regr: 0.1495 - detector_cls: 0.3616 - detector_regr: 0.1601
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.886113886113886
# Classifier accuracy for bounding boxes from RPN: 0.86021875
# Loss RPN classifier: 0.7884617084153037
# Loss RPN regression: 0.14930579466186464
# Loss Detector classifier: 0.3510224174899049
# Loss Detector regression: 0.15835860623791814
# Elapsed time: 478.4635829925537
# Epoch 47/100
#  998/1000 [============================>.] - ETA: 0s - rpn_cls: 0.7420 - rpn_regr: 0.1462 - detector_cls: 0.3160 - detector_regr: 0.1504Average number of overlapping bounding boxes from RPN = 19.494 for 1000 previous iterations
# 1000/1000 [==============================] - 480s 480ms/step - rpn_cls: 0.7420 - rpn_regr: 0.1462 - detector_cls: 0.3160 - detector_regr: 0.1504
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.469
# Classifier accuracy for bounding boxes from RPN: 0.87071875
# Loss RPN classifier: 0.748311136356564
# Loss RPN regression: 0.1495446307309903
# Loss Detector classifier: 0.32359188252082094
# Loss Detector regression: 0.15016785204969346
# Elapsed time: 479.60939383506775
# Epoch 48/100
#  998/1000 [============================>.] - ETA: 0s - rpn_cls: 0.7875 - rpn_regr: 0.1383 - detector_cls: 0.3277 - detector_regr: 0.1410Average number of overlapping bounding boxes from RPN = 19.585 for 1000 previous iterations
# 1000/1000 [==============================] - 481s 481ms/step - rpn_cls: 0.7876 - rpn_regr: 0.1383 - detector_cls: 0.3277 - detector_regr: 0.1410
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.589
# Classifier accuracy for bounding boxes from RPN: 0.86953125
# Loss RPN classifier: 0.815866924668311
# Loss RPN regression: 0.14036853714240716
# Loss Detector classifier: 0.3261142950132489
# Loss Detector regression: 0.14540397308394312
# Elapsed time: 480.78046131134033
# Epoch 49/100
#  998/1000 [============================>.] - ETA: 0s - rpn_cls: 0.6850 - rpn_regr: 0.1523 - detector_cls: 0.3366 - detector_regr: 0.1493Average number of overlapping bounding boxes from RPN = 19.223 for 1000 previous iterations
# 1000/1000 [==============================] - 474s 474ms/step - rpn_cls: 0.6849 - rpn_regr: 0.1523 - detector_cls: 0.3365 - detector_regr: 0.1493
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.226
# Classifier accuracy for bounding boxes from RPN: 0.866125
# Loss RPN classifier: 0.6639794183943828
# Loss RPN regression: 0.1481031447330024
# Loss Detector classifier: 0.3338793702640105
# Loss Detector regression: 0.14797849751636385
# Elapsed time: 473.7884864807129
# Total loss decreased from 1.3645689168279904 to 1.2939404309077593, saving weights
# Epoch 50/100
#  998/1000 [============================>.] - ETA: 0s - rpn_cls: 0.5863 - rpn_regr: 0.1408 - detector_cls: 0.3149 - detector_regr: 0.1500Average number of overlapping bounding boxes from RPN = 20.028 for 1000 previous iterations
# 1000/1000 [==============================] - 478s 478ms/step - rpn_cls: 0.5865 - rpn_regr: 0.1408 - detector_cls: 0.3150 - detector_regr: 0.1500
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.053
# Classifier accuracy for bounding boxes from RPN: 0.86890625
# Loss RPN classifier: 0.675448357992064
# Loss RPN regression: 0.14295399243338033
# Loss Detector classifier: 0.32744711603829635
# Loss Detector regression: 0.1521245443765074
# Elapsed time: 479.0491871833801
# Epoch 51/100
#  998/1000 [============================>.] - ETA: 0s - rpn_cls: 0.6905 - rpn_regr: 0.1450 - detector_cls: 0.3308 - detector_regr: 0.1526Average number of overlapping bounding boxes from RPN = 19.9 for 1000 previous iterations
# 1000/1000 [==============================] - 481s 481ms/step - rpn_cls: 0.6905 - rpn_regr: 0.1450 - detector_cls: 0.3308 - detector_regr: 0.1526
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.889
# Classifier accuracy for bounding boxes from RPN: 0.86653125
# Loss RPN classifier: 0.7127310524177743
# Loss RPN regression: 0.14675612394791096
# Loss Detector classifier: 0.332053985780105
# Loss Detector regression: 0.1545678799059242
# Elapsed time: 481.06268644332886
# Epoch 52/100
#  998/1000 [============================>.] - ETA: 0s - rpn_cls: 0.6920 - rpn_regr: 0.1396 - detector_cls: 0.3327 - detector_regr: 0.1483Average number of overlapping bounding boxes from RPN = 19.294 for 1000 previous iterations
# 1000/1000 [==============================] - 473s 473ms/step - rpn_cls: 0.6919 - rpn_regr: 0.1396 - detector_cls: 0.3326 - detector_regr: 0.1483
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.338
# Classifier accuracy for bounding boxes from RPN: 0.87653125
# Loss RPN classifier: 0.6457164985076748
# Loss RPN regression: 0.14206208265025635
# Loss Detector classifier: 0.31022908846195785
# Loss Detector regression: 0.14432192664407192
# Elapsed time: 472.68077206611633
# Total loss decreased from 1.2939404309077593 to 1.2423295962639607, saving weights
# Epoch 53/100
#  998/1000 [============================>.] - ETA: 0s - rpn_cls: 0.6549 - rpn_regr: 0.1366 - detector_cls: 0.2939 - detector_regr: 0.1387Average number of overlapping bounding boxes from RPN = 19.963 for 1000 previous iterations
# 1000/1000 [==============================] - 471s 471ms/step - rpn_cls: 0.6548 - rpn_regr: 0.1366 - detector_cls: 0.2939 - detector_regr: 0.1387
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.932
# Classifier accuracy for bounding boxes from RPN: 0.881
# Loss RPN classifier: 0.6375652932976286
# Loss RPN regression: 0.13361031185567845
# Loss Detector classifier: 0.2941664437903237
# Loss Detector regression: 0.1380647104009986
# Elapsed time: 472.5583794116974
# Total loss decreased from 1.2423295962639607 to 1.2034067593446294, saving weights
# Epoch 54/100
#  997/1000 [============================>.] - ETA: 1s - rpn_cls: 0.6408 - rpn_regr: 0.1411 - detector_cls: 0.3116 - detector_regr: 0.1398Average number of overlapping bounding boxes from RPN = 20.437 for 1000 previous iterations
# 1000/1000 [==============================] - 482s 482ms/step - rpn_cls: 0.6410 - rpn_regr: 0.1411 - detector_cls: 0.3116 - detector_regr: 0.1398
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.44055944055944
# Classifier accuracy for bounding boxes from RPN: 0.87259375
# Loss RPN classifier: 0.7043511509815
# Loss RPN regression: 0.1429902606140822
# Loss Detector classifier: 0.31731014254875484
# Loss Detector regression: 0.1427104855198413
# Elapsed time: 483.0618681907654
# Epoch 55/100
#  997/1000 [============================>.] - ETA: 1s - rpn_cls: 0.6434 - rpn_regr: 0.1429 - detector_cls: 0.3021 - detector_regr: 0.1398Average number of overlapping bounding boxes from RPN = 19.99 for 1000 previous iterations
# 1000/1000 [==============================] - 480s 480ms/step - rpn_cls: 0.6435 - rpn_regr: 0.1429 - detector_cls: 0.3021 - detector_regr: 0.1398
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.962
# Classifier accuracy for bounding boxes from RPN: 0.87815625
# Loss RPN classifier: 0.6589647784115044
# Loss RPN regression: 0.14238659647945315
# Loss Detector classifier: 0.30407565886480736
# Loss Detector regression: 0.13912228439562022
# Elapsed time: 480.2198975086212
# Epoch 56/100
#  997/1000 [============================>.] - ETA: 1s - rpn_cls: 0.6345 - rpn_regr: 0.1442 - detector_cls: 0.3071 - detector_regr: 0.1439Average number of overlapping bounding boxes from RPN = 19.439 for 1000 previous iterations
# 1000/1000 [==============================] - 473s 473ms/step - rpn_cls: 0.6345 - rpn_regr: 0.1441 - detector_cls: 0.3071 - detector_regr: 0.1439
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.456
# Classifier accuracy for bounding boxes from RPN: 0.87725
# Loss RPN classifier: 0.6188872488489657
# Loss RPN regression: 0.14154872458567844
# Loss Detector classifier: 0.30644211717508735
# Loss Detector regression: 0.1423898854246363
# Elapsed time: 473.0792372226715
# Epoch 57/100
#  997/1000 [============================>.] - ETA: 1s - rpn_cls: 0.6871 - rpn_regr: 0.1554 - detector_cls: 0.3102 - detector_regr: 0.1459Average number of overlapping bounding boxes from RPN = 19.395 for 1000 previous iterations
# 1000/1000 [==============================] - 475s 475ms/step - rpn_cls: 0.6871 - rpn_regr: 0.1554 - detector_cls: 0.3102 - detector_regr: 0.1458
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.396
# Classifier accuracy for bounding boxes from RPN: 0.8745625
# Loss RPN classifier: 0.6828029726543774
# Loss RPN regression: 0.1472942456677556
# Loss Detector classifier: 0.311241578255489
# Loss Detector regression: 0.14361381419748068
# Elapsed time: 475.0715820789337
# Epoch 58/100
#  997/1000 [============================>.] - ETA: 1s - rpn_cls: 0.6888 - rpn_regr: 0.1401 - detector_cls: 0.2891 - detector_regr: 0.1311Average number of overlapping bounding boxes from RPN = 19.43 for 1000 previous iterations
# 1000/1000 [==============================] - 473s 473ms/step - rpn_cls: 0.6887 - rpn_regr: 0.1401 - detector_cls: 0.2891 - detector_regr: 0.1311
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.399
# Classifier accuracy for bounding boxes from RPN: 0.88896875
# Loss RPN classifier: 0.6708286612164188
# Loss RPN regression: 0.14009135960973798
# Loss Detector classifier: 0.2774768983310059
# Loss Detector regression: 0.12892347602918744
# Elapsed time: 472.9300215244293
# Epoch 59/100
#  997/1000 [============================>.] - ETA: 1s - rpn_cls: 0.5411 - rpn_regr: 0.1260 - detector_cls: 0.2638 - detector_regr: 0.1296Average number of overlapping bounding boxes from RPN = 19.706 for 1000 previous iterations
# 1000/1000 [==============================] - 472s 472ms/step - rpn_cls: 0.5411 - rpn_regr: 0.1260 - detector_cls: 0.2638 - detector_regr: 0.1296
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.741
# Classifier accuracy for bounding boxes from RPN: 0.888875
# Loss RPN classifier: 0.5512507377344018
# Loss RPN regression: 0.13220504502905533
# Loss Detector classifier: 0.27438294200412927
# Loss Detector regression: 0.1293861697418615
# Elapsed time: 472.2917468547821
# Total loss decreased from 1.2034067593446294 to 1.0872248945094478, saving weights
# Epoch 60/100
#  997/1000 [============================>.] - ETA: 1s - rpn_cls: 0.5867 - rpn_regr: 0.1411 - detector_cls: 0.2878 - detector_regr: 0.1313Average number of overlapping bounding boxes from RPN = 19.38 for 1000 previous iterations
# 1000/1000 [==============================] - 478s 478ms/step - rpn_cls: 0.5869 - rpn_regr: 0.1411 - detector_cls: 0.2878 - detector_regr: 0.1313
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.357
# Classifier accuracy for bounding boxes from RPN: 0.8835
# Loss RPN classifier: 0.6623577041281383
# Loss RPN regression: 0.1417520825972315
# Loss Detector classifier: 0.2917008363345958
# Loss Detector regression: 0.13240312198363244
# Elapsed time: 479.02669858932495
# Epoch 61/100
#  997/1000 [============================>.] - ETA: 1s - rpn_cls: 0.6979 - rpn_regr: 0.1437 - detector_cls: 0.2939 - detector_regr: 0.1337Average number of overlapping bounding boxes from RPN = 20.126 for 1000 previous iterations
# 1000/1000 [==============================] - 472s 472ms/step - rpn_cls: 0.6979 - rpn_regr: 0.1437 - detector_cls: 0.2939 - detector_regr: 0.1337
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.123
# Classifier accuracy for bounding boxes from RPN: 0.88028125
# Loss RPN classifier: 0.7081381452961352
# Loss RPN regression: 0.14452955297823064
# Loss Detector classifier: 0.29811566734383815
# Loss Detector regression: 0.13531040646042675
# Elapsed time: 471.54126238822937
# Epoch 62/100
#  997/1000 [============================>.] - ETA: 1s - rpn_cls: 0.5685 - rpn_regr: 0.1361 - detector_cls: 0.2846 - detector_regr: 0.1345Average number of overlapping bounding boxes from RPN = 20.219 for 1000 previous iterations
# 1000/1000 [==============================] - 480s 480ms/step - rpn_cls: 0.5687 - rpn_regr: 0.1362 - detector_cls: 0.2846 - detector_regr: 0.1345
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.23
# Classifier accuracy for bounding boxes from RPN: 0.88475
# Loss RPN classifier: 0.6073268713782024
# Loss RPN regression: 0.13946725322213024
# Loss Detector classifier: 0.28630583601258697
# Loss Detector regression: 0.1343704537767917
# Elapsed time: 480.3585088253021
# Epoch 63/100
#  997/1000 [============================>.] - ETA: 1s - rpn_cls: 0.6351 - rpn_regr: 0.1390 - detector_cls: 0.3137 - detector_regr: 0.1388Average number of overlapping bounding boxes from RPN = 20.735 for 1000 previous iterations
# 1000/1000 [==============================] - 482s 482ms/step - rpn_cls: 0.6350 - rpn_regr: 0.1390 - detector_cls: 0.3137 - detector_regr: 0.1388
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.715
# Classifier accuracy for bounding boxes from RPN: 0.88146875
# Loss RPN classifier: 0.6172348230739851
# Loss RPN regression: 0.14199584902403875
# Loss Detector classifier: 0.29973923896066845
# Loss Detector regression: 0.13760798273794353
# Elapsed time: 482.3149209022522
# Epoch 64/100
#  997/1000 [============================>.] - ETA: 1s - rpn_cls: 0.6048 - rpn_regr: 0.1297 - detector_cls: 0.2643 - detector_regr: 0.1277Average number of overlapping bounding boxes from RPN = 20.045 for 1000 previous iterations
# 1000/1000 [==============================] - 475s 475ms/step - rpn_cls: 0.6048 - rpn_regr: 0.1297 - detector_cls: 0.2643 - detector_regr: 0.1277
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.036
# Classifier accuracy for bounding boxes from RPN: 0.8949375
# Loss RPN classifier: 0.5951941907946267
# Loss RPN regression: 0.13432839117501863
# Loss Detector classifier: 0.2605120049182296
# Loss Detector regression: 0.12254738431051374
# Elapsed time: 475.2090337276459
# Epoch 65/100
#  997/1000 [============================>.] - ETA: 1s - rpn_cls: 0.5700 - rpn_regr: 0.1391 - detector_cls: 0.2683 - detector_regr: 0.1203Average number of overlapping bounding boxes from RPN = 19.607 for 1000 previous iterations
# 1000/1000 [==============================] - 475s 475ms/step - rpn_cls: 0.5700 - rpn_regr: 0.1391 - detector_cls: 0.2683 - detector_regr: 0.1203
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.634
# Classifier accuracy for bounding boxes from RPN: 0.8935
# Loss RPN classifier: 0.5832981884512446
# Loss RPN regression: 0.13483487188839355
# Loss Detector classifier: 0.2683532896628603
# ...
# Loss Detector regression: 0.11437702104821801
# Elapsed time: 473.8550052642822
# Total loss decreased from 0.9924602108082609 to 0.9652948862829506, saving weights
# Epoch 80/100
#  996/1000 [============================>.] - ETA: 1s - rpn_cls: 0.5046 - rpn_regr: 0.1272 - detector_cls: 0.2375 - detector_regr: 0.1098Average number of overlapping bounding boxes from RPN = 19.89 for 1000 previous iterations
# 1000/1000 [==============================] - 479s 479ms/step - rpn_cls: 0.5048 - rpn_regr: 0.1272 - detector_cls: 0.2376 - detector_regr: 0.1098
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.879
# Classifier accuracy for bounding boxes from RPN: 0.901375
# Loss RPN classifier: 0.5467060639295878
# Loss RPN regression: 0.1328378055677749
# Loss Detector classifier: 0.24851055293367244
# Loss Detector regression: 0.1156607203669846
# Elapsed time: 480.2474436759949
# Epoch 81/100
#  996/1000 [============================>.] - ETA: 1s - rpn_cls: 0.4361 - rpn_regr: 0.1272 - detector_cls: 0.2407 - detector_regr: 0.1078Average number of overlapping bounding boxes from RPN = 20.25 for 1000 previous iterations
# 1000/1000 [==============================] - 479s 479ms/step - rpn_cls: 0.4361 - rpn_regr: 0.1272 - detector_cls: 0.2407 - detector_regr: 0.1078
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.254
# Classifier accuracy for bounding boxes from RPN: 0.90434375
# Loss RPN classifier: 0.4477371829634262
# Loss RPN regression: 0.12805377900134773
# Loss Detector classifier: 0.23575688017345964
# Loss Detector regression: 0.10827386619057507
# Elapsed time: 478.59236216545105
# Total loss decreased from 0.9652948862829506 to 0.9198217083288086, saving weights
# Epoch 82/100
#  996/1000 [============================>.] - ETA: 1s - rpn_cls: 0.5117 - rpn_regr: 0.1211 - detector_cls: 0.2402 - detector_regr: 0.1051Average number of overlapping bounding boxes from RPN = 20.614 for 1000 previous iterations
# 1000/1000 [==============================] - 477s 477ms/step - rpn_cls: 0.5116 - rpn_regr: 0.1212 - detector_cls: 0.2402 - detector_regr: 0.1051
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.641
# Classifier accuracy for bounding boxes from RPN: 0.9021875
# Loss RPN classifier: 0.477575416171758
# Loss RPN regression: 0.12554043423011899
# Loss Detector classifier: 0.24162395352171734
# Loss Detector regression: 0.10600367489270866
# Elapsed time: 477.80422949790955
# Epoch 83/100
#  995/1000 [============================>.] - ETA: 2s - rpn_cls: 0.4721 - rpn_regr: 0.1294 - detector_cls: 0.2389 - detector_regr: 0.1077Average number of overlapping bounding boxes from RPN = 20.58 for 1000 previous iterations
# 1000/1000 [==============================] - 477s 477ms/step - rpn_cls: 0.4721 - rpn_regr: 0.1295 - detector_cls: 0.2389 - detector_regr: 0.1077
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.516483516483518
# Classifier accuracy for bounding boxes from RPN: 0.90396875
# Loss RPN classifier: 0.4848931165046885
# Loss RPN regression: 0.13266690794355235
# Loss Detector classifier: 0.2399710744363256
# Loss Detector regression: 0.10955826804507524
# Elapsed time: 477.25608110427856
# Epoch 84/100
#  995/1000 [============================>.] - ETA: 2s - rpn_cls: 0.5560 - rpn_regr: 0.1361 - detector_cls: 0.2520 - detector_regr: 0.1102Average number of overlapping bounding boxes from RPN = 20.265 for 1000 previous iterations
# 1000/1000 [==============================] - 480s 480ms/step - rpn_cls: 0.5558 - rpn_regr: 0.1361 - detector_cls: 0.2520 - detector_regr: 0.1102
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.32
# Classifier accuracy for bounding boxes from RPN: 0.89996875
# Loss RPN classifier: 0.5165356039845479
# Loss RPN regression: 0.1328339942334569
# Loss Detector classifier: 0.25054457063105656
# Loss Detector regression: 0.1100949274469167
# Elapsed time: 480.1211631298065
# Epoch 85/100
#  995/1000 [============================>.] - ETA: 2s - rpn_cls: 0.5629 - rpn_regr: 0.1261 - detector_cls: 0.2445 - detector_regr: 0.1128Average number of overlapping bounding boxes from RPN = 20.083 for 1000 previous iterations
# 1000/1000 [==============================] - 467s 467ms/step - rpn_cls: 0.5628 - rpn_regr: 0.1261 - detector_cls: 0.2444 - detector_regr: 0.1128
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.054
# Classifier accuracy for bounding boxes from RPN: 0.90296875
# Loss RPN classifier: 0.5363997231148074
# Loss RPN regression: 0.12320427449210547
# Loss Detector classifier: 0.23925587120233105
# Loss Detector regression: 0.11124755982588977
# Elapsed time: 466.79947447776794
# Epoch 86/100
#  995/1000 [============================>.] - ETA: 2s - rpn_cls: 0.4737 - rpn_regr: 0.1283 - detector_cls: 0.2389 - detector_regr: 0.1069Average number of overlapping bounding boxes from RPN = 19.919 for 1000 previous iterations
# 1000/1000 [==============================] - 471s 471ms/step - rpn_cls: 0.4739 - rpn_regr: 0.1283 - detector_cls: 0.2389 - detector_regr: 0.1069
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.907
# Classifier accuracy for bounding boxes from RPN: 0.90590625
# Loss RPN classifier: 0.5062377820884022
# Loss RPN regression: 0.1287782475319691
# Loss Detector classifier: 0.2351905377882067
# Loss Detector regression: 0.10476312087196857
# Elapsed time: 471.18295407295227
# Epoch 87/100
#  995/1000 [============================>.] - ETA: 2s - rpn_cls: 0.4845 - rpn_regr: 0.1324 - detector_cls: 0.2371 - detector_regr: 0.1061Average number of overlapping bounding boxes from RPN = 20.397 for 1000 previous iterations
# 1000/1000 [==============================] - 481s 481ms/step - rpn_cls: 0.4845 - rpn_regr: 0.1324 - detector_cls: 0.2371 - detector_regr: 0.1061
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.447
# Classifier accuracy for bounding boxes from RPN: 0.90903125
# Loss RPN classifier: 0.4986192502829872
# Loss RPN regression: 0.13059340224112384
# Loss Detector classifier: 0.23084837335601333
# Loss Detector regression: 0.10344967975933105
# Elapsed time: 480.534099817276
# Epoch 88/100
#  995/1000 [============================>.] - ETA: 2s - rpn_cls: 0.4176 - rpn_regr: 0.1199 - detector_cls: 0.2292 - detector_regr: 0.1026Average number of overlapping bounding boxes from RPN = 20.365 for 1000 previous iterations
# 1000/1000 [==============================] - 475s 475ms/step - rpn_cls: 0.4178 - rpn_regr: 0.1199 - detector_cls: 0.2293 - detector_regr: 0.1026
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.349
# Classifier accuracy for bounding boxes from RPN: 0.90765625
# Loss RPN classifier: 0.45908382903068656
# Loss RPN regression: 0.12640727136441274
# Loss Detector classifier: 0.23164064709097146
# Loss Detector regression: 0.10267147708497941
# Elapsed time: 475.1331100463867
# Total loss decreased from 0.9198217083288086 to 0.9198032245710501, saving weights
# Epoch 89/100
#  995/1000 [============================>.] - ETA: 2s - rpn_cls: 0.5152 - rpn_regr: 0.1262 - detector_cls: 0.2366 - detector_regr: 0.1002Average number of overlapping bounding boxes from RPN = 20.946 for 1000 previous iterations
# 1000/1000 [==============================] - 480s 480ms/step - rpn_cls: 0.5150 - rpn_regr: 0.1262 - detector_cls: 0.2366 - detector_regr: 0.1002
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.951
# Classifier accuracy for bounding boxes from RPN: 0.90271875
# Loss RPN classifier: 0.47862698843383017
# Loss RPN regression: 0.13134422515076585
# Loss Detector classifier: 0.23743279276392423
# Loss Detector regression: 0.10578497802931816
# Elapsed time: 481.4935836791992
# Epoch 90/100
#  994/1000 [============================>.] - ETA: 2s - rpn_cls: 0.5038 - rpn_regr: 0.1207 - detector_cls: 0.2410 - detector_regr: 0.1083Average number of overlapping bounding boxes from RPN = 20.722 for 1000 previous iterations
# 1000/1000 [==============================] - 474s 474ms/step - rpn_cls: 0.5038 - rpn_regr: 0.1208 - detector_cls: 0.2410 - detector_regr: 0.1083
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.696303696303698
# Classifier accuracy for bounding boxes from RPN: 0.90565625
# Loss RPN classifier: 0.5096013667950042
# Loss RPN regression: 0.12372103821160271
# Loss Detector classifier: 0.23570940399123355
# Loss Detector regression: 0.10604449152201414
# Elapsed time: 473.81539034843445
# Epoch 91/100
#  994/1000 [============================>.] - ETA: 2s - rpn_cls: 0.4159 - rpn_regr: 0.1304 - detector_cls: 0.2401 - detector_regr: 0.1054Average number of overlapping bounding boxes from RPN = 20.502 for 1000 previous iterations
# 1000/1000 [==============================] - 472s 472ms/step - rpn_cls: 0.4161 - rpn_regr: 0.1304 - detector_cls: 0.2401 - detector_regr: 0.1054
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.494
# Classifier accuracy for bounding boxes from RPN: 0.90515625
# Loss RPN classifier: 0.4523396948992637
# Loss RPN regression: 0.13071410234179348
# Loss Detector classifier: 0.23757416536573145
# Loss Detector regression: 0.10315305739454925
# Elapsed time: 472.14303255081177
# Epoch 92/100
#  994/1000 [============================>.] - ETA: 2s - rpn_cls: 0.5461 - rpn_regr: 0.1216 - detector_cls: 0.2429 - detector_regr: 0.1034Average number of overlapping bounding boxes from RPN = 20.127 for 1000 previous iterations
# 1000/1000 [==============================] - 469s 469ms/step - rpn_cls: 0.5458 - rpn_regr: 0.1215 - detector_cls: 0.2428 - detector_regr: 0.1034
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.156
# Classifier accuracy for bounding boxes from RPN: 0.909375
# Loss RPN classifier: 0.4949536214950363
# Loss RPN regression: 0.1194718176983297
# Loss Detector classifier: 0.22978776353716968
# Loss Detector regression: 0.09860187928564847
# Elapsed time: 468.6020276546478
# Epoch 93/100
#  994/1000 [============================>.] - ETA: 2s - rpn_cls: 0.4164 - rpn_regr: 0.1196 - detector_cls: 0.2199 - detector_regr: 0.0968Average number of overlapping bounding boxes from RPN = 20.027 for 1000 previous iterations
# 1000/1000 [==============================] - 472s 472ms/step - rpn_cls: 0.4168 - rpn_regr: 0.1196 - detector_cls: 0.2199 - detector_regr: 0.0968
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.988
# Classifier accuracy for bounding boxes from RPN: 0.9094375
# Loss RPN classifier: 0.4756476422803209
# Loss RPN regression: 0.12302672807849012
# Loss Detector classifier: 0.22297720137704163
# Loss Detector regression: 0.09771767771802843
# Elapsed time: 472.09781551361084
# Total loss decreased from 0.9198032245710501 to 0.919369249453881, saving weights
# Epoch 94/100
#  994/1000 [============================>.] - ETA: 2s - rpn_cls: 0.5147 - rpn_regr: 0.1259 - detector_cls: 0.2323 - detector_regr: 0.0998Average number of overlapping bounding boxes from RPN = 20.821 for 1000 previous iterations
# 1000/1000 [==============================] - 475s 475ms/step - rpn_cls: 0.5143 - rpn_regr: 0.1259 - detector_cls: 0.2323 - detector_regr: 0.0998
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.851
# Classifier accuracy for bounding boxes from RPN: 0.9068125
# Loss RPN classifier: 0.4431421304105478
# Loss RPN regression: 0.123623520700261
# Loss Detector classifier: 0.23225015739910304
# Loss Detector regression: 0.0996145453993231
# Elapsed time: 476.2762870788574
# Total loss decreased from 0.919369249453881 to 0.898630353909235, saving weights
# Epoch 95/100
#  994/1000 [============================>.] - ETA: 2s - rpn_cls: 0.4337 - rpn_regr: 0.1186 - detector_cls: 0.2249 - detector_regr: 0.1021Average number of overlapping bounding boxes from RPN = 21.058 for 1000 previous iterations
# 1000/1000 [==============================] - 475s 475ms/step - rpn_cls: 0.4337 - rpn_regr: 0.1186 - detector_cls: 0.2249 - detector_regr: 0.1021
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.062
# Classifier accuracy for bounding boxes from RPN: 0.91328125
# Loss RPN classifier: 0.4310724798602157
# Loss RPN regression: 0.12629317214153707
# Loss Detector classifier: 0.22446645450289363
# Loss Detector regression: 0.09786749175237491
# Elapsed time: 475.9713063240051
# Total loss decreased from 0.898630353909235 to 0.8796995982570213, saving weights
# Epoch 96/100
#  994/1000 [============================>.] - ETA: 2s - rpn_cls: 0.4591 - rpn_regr: 0.1224 - detector_cls: 0.2276 - detector_regr: 0.1030Average number of overlapping bounding boxes from RPN = 20.611 for 1000 previous iterations
# 1000/1000 [==============================] - 470s 470ms/step - rpn_cls: 0.4590 - rpn_regr: 0.1224 - detector_cls: 0.2276 - detector_regr: 0.1029
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.596
# Classifier accuracy for bounding boxes from RPN: 0.9116875
# Loss RPN classifier: 0.4521149542735865
# Loss RPN regression: 0.12508246624574532
# Loss Detector classifier: 0.2226070532425074
# Loss Detector regression: 0.09925928401201964
# Elapsed time: 471.290593624115
# Epoch 97/100
#  994/1000 [============================>.] - ETA: 2s - rpn_cls: 0.4811 - rpn_regr: 0.1314 - detector_cls: 0.2392 - detector_regr: 0.1021Average number of overlapping bounding boxes from RPN = 21.18 for 1000 previous iterations
# 1000/1000 [==============================] - 477s 477ms/step - rpn_cls: 0.4810 - rpn_regr: 0.1313 - detector_cls: 0.2392 - detector_regr: 0.1021
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.183
# Classifier accuracy for bounding boxes from RPN: 0.90525
# Loss RPN classifier: 0.46459714822644027
# Loss RPN regression: 0.12796650225901976
# Loss Detector classifier: 0.23773856295133008
# Loss Detector regression: 0.10329293093923479
# Elapsed time: 477.2879157066345
# Epoch 98/100
#  994/1000 [============================>.] - ETA: 2s - rpn_cls: 0.4462 - rpn_regr: 0.1155 - detector_cls: 0.2186 - detector_regr: 0.0945Average number of overlapping bounding boxes from RPN = 20.902 for 1000 previous iterations
# 1000/1000 [==============================] - 474s 474ms/step - rpn_cls: 0.4463 - rpn_regr: 0.1155 - detector_cls: 0.2186 - detector_regr: 0.0945
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.96
# Classifier accuracy for bounding boxes from RPN: 0.9116875
# Loss RPN classifier: 0.4542878157173703
# Loss RPN regression: 0.116862579948036
# Loss Detector classifier: 0.22102946727583184
# Loss Detector regression: 0.09368167913239449
# Elapsed time: 474.3358976840973
# Epoch 99/100
#  994/1000 [============================>.] - ETA: 2s - rpn_cls: 0.4323 - rpn_regr: 0.1113 - detector_cls: 0.2093 - detector_regr: 0.0909Average number of overlapping bounding boxes from RPN = 20.207 for 1000 previous iterations
# 1000/1000 [==============================] - 466s 466ms/step - rpn_cls: 0.4322 - rpn_regr: 0.1113 - detector_cls: 0.2093 - detector_regr: 0.0909
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.141
# Classifier accuracy for bounding boxes from RPN: 0.915625
# Loss RPN classifier: 0.4166899826954636
# Loss RPN regression: 0.11250563631160185
# Loss Detector classifier: 0.21043106844881548
# Loss Detector regression: 0.09192406000569463
# Elapsed time: 465.6353795528412
# Total loss decreased from 0.8796995982570213 to 0.8315507474615756, saving weights
# Epoch 100/100
#  994/1000 [============================>.] - ETA: 2s - rpn_cls: 0.4181 - rpn_regr: 0.1208 - detector_cls: 0.2014 - detector_regr: 0.0897Average number of overlapping bounding boxes from RPN = 20.527 for 1000 previous iterations
# 1000/1000 [==============================] - 476s 476ms/step - rpn_cls: 0.4182 - rpn_regr: 0.1208 - detector_cls: 0.2014 - detector_regr: 0.0898
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.547
# Classifier accuracy for bounding boxes from RPN: 0.91759375
# Loss RPN classifier: 0.4452489337943665
# Loss RPN regression: 0.12688135462696665
# Loss Detector classifier: 0.20684725297658588
# Loss Detector regression: 0.09263006958924234
# Elapsed time: 476.83812499046326
# Training complete, exiting.
